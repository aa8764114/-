# %% [markdown]
# ## churn.all

# %%
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/churn.all.csv')

#刪除不要的欄位
data.drop(['id'], inplace=True, axis=1)
data.drop(['phone_number'], inplace=True, axis=1)

#將目標屬性轉為數字
import numpy as np
data['Churn'] = np.where(data['Churn'] == ' False', 0, 1)

#分割輸入屬性及目標屬性

#輸入屬性
x_ = data.drop(['Churn'], axis=1)#同上方法刪除行

#目標屬性
y_ = data['Churn']

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
        ('scaler', scaler()),
        ('dummies', dummies()),
        #('filter', feature_selection(method = 'anova_kf', p_threshold = 1)),
        #('sfs',feature_selection(method = 'sfs', sfs_direction = direction, sfs_scoring = scoring, sfs_cv = cv, sfs_estimator = estimator))
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)
# Out:
# 2021 09:26:15 INFO Fit Columns Type Already Success!!!
# 2021 09:26:15 INFO Transform Columns Type Success!!!
# 2021 09:26:15 INFO scaler Success!!!
# 2021 09:26:15 INFO dummies Success!!!
# (5000, 87)

# %% [markdown]
# ## bank

# %% [markdown]
# import pandas as pd
#
# #放在不同資料夾用絕對路徑
# data = pd.read_csv('bank.csv')
#
# #刪除ID
# #data.drop(['id'], inplace=True, axis=1)
#
# #將目標屬性轉為數字
# import numpy as np
# data['y'] = np.where(data['y'] == 'no', 0, 1)
#
# #分割輸入屬性及目標屬性
#
# #輸入屬性
# x_ = data.drop(['y'], axis=1)#同上方法刪除行
# #x_ = data.drop(['phone_number'], axis=1)#同上方法刪除行
#
# #目標屬性
# y_ = data['y']
#
# #去除錯誤值及空值填補
# from sklearn.pipeline import Pipeline
# from data_preprocessing_pipeline import *
# from feature_engineering import *
#
# pipe = Pipeline(
#        [
#         ('Wrong_Value',wrong_value_fillna(wrong_value=['unknown'])),
#         ('Null_Value', xgb_fill()),
#         ('define_column_type', define_column_type()),
#         ('scaler', scaler()),
#         ('dummies', dummies()),
#        ])
#
# x_ = pipe.fit_transform(x_, y_)
# print(x_.shape)

# %% [markdown]
# ## WPBC

# %% [markdown]
# import pandas as pd
#
# #放在不同資料夾用絕對路徑
# wpbc = pd.read_csv('wpbc.csv', header=None)
#
# #刪除ID
# wpbc.drop([0], inplace=True, axis=1)
#
# #將目標屬性轉為數字
# import numpy as np
# wpbc[1] = np.where(wpbc[1] == 'N', 0, 1)
#
# #分割輸入屬性及目標屬性
#
# #輸入屬性
# x_ = wpbc.drop([1], axis=1)#同上方法刪除行
#
# #目標屬性
# y_ = wpbc[1]
#
# #去除錯誤值及空值填補
# from sklearn.pipeline import Pipeline
# from data_preprocessing_pipeline import *
# from feature_engineering import *
#
# pipe = Pipeline(
#        [
#          ('Wrong_Value',wrong_value_fillna(wrong_value=['?'])),
#          ('column_type', define_column_type()),
#          #('Outlier', fix_outlier(how='quartile')),
#
#          ('Null_Value', xgb_fill()),
#          #('num_log', num_log()),
#
#          ('Wrong_Value2',wrong_value_fillna(wrong_value=[np.nan, float('-inf')])),
#          ('Null_Value2', xgb_fill()),
#
#        ])
#
# x_ = pipe.fit_transform(x_, y_)
# print(x_.shape)

# %% [markdown]
# ## 用產生資料測試

# %% [markdown]
# from sklearn.datasets import make_classification
# import pandas as pd
#
# x_, y_ = make_classification(n_samples=5000, n_features=100,
#                              n_informative=60, n_redundant=20,
#                              n_classes=2, random_state=0, shuffle=True)
#
# x_ = pd.DataFrame(x_)
# y_ = pd.DataFrame(y_)

# %% [markdown]
# x2 = x_
# y2 = y_

# %% [markdown]
# ## 將index轉換為欄位名稱

# %%
def index_to_colname(indexs, oridata):
    colname = []
    for i in indexs:
        colname.append(list(x_.columns)[i])
    
    return(colname)

# %% [markdown]
# ## 輸入模型將屬性重要性轉為index輸出

# %%
def importance_to_index(clf, prob):
    importances = list(clf.feature_importances_)
    s = importances
    s2 = sorted(range(len(s)), key=lambda k: s[k], reverse=True)
    return s2[:int(len(s2)*prob)]

# %% [markdown]
# ## 交叉驗證AUC

# %%
#計算AUC函數
def get_auc(model, x, y):
    
    '''
    model : 用甚麼方式建模
    x : 輸入屬性
    y : 目標屬性
    '''
    import numpy as np
    from sklearn import metrics
    
    #建模
    #model.fit(x, y)

    #用訓練資料測試
    fpr, tpr, thresholds = metrics.roc_curve(y, model.predict(x))
    auc = metrics.auc(fpr, tpr)

    print('這次的AUC : ', auc,'\n')
    return auc

# %%
#計算f1函數
def get_f1(model, x, y):
    
    '''
    model : 用甚麼方式建模
    x : 輸入屬性
    y : 目標屬性
    '''
    import numpy as np
    from sklearn.metrics import f1_score
    
    #建模
    #model.fit(x, y)

    #用訓練資料測試
    f1 = f1_score(y, model.predict(x), average='binary')

    print('這次的f1 : ', f1,'\n')
    return f1

# %% [markdown]
# from sklearn.metrics import f1_score
#
# y_true = [0, 1, 2, 0, 1, 2]
# y_pred = [0, 2, 1, 0, 0, 1]
# print(f1_score(y_true, y_pred, average='macro'))  # 0.26666666666666666
# print(f1_score(y_true, y_pred, average='micro'))  # 0.3333333333333333
# print(f1_score(y_true, y_pred, average='weighted'))  # 0.26666666666666666
# print(f1_score(y_true, y_pred, average=None))  # [0.8 0.  0. ]

# %%
from sklearn.ensemble import AdaBoostClassifierZe
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import numpy as np


#交叉驗證，分層隨機抽樣
from sklearn.model_selection import StratifiedKFold
import random as rd



fs_method = ['anova_kf', 'gini', 'entropy', 'rf_gini', 'rf_entropy', 'xgb', False]
# fs_method = ['xgb', False]



for fsMethod in fs_method:
    
    f1 = [] #存不同方法的交叉驗證平均f1
    AUC = [] #存不同方法的交叉驗證平均AUC
    
    ans_auc = [] #儲存每次交叉驗證的AUC
    ans_f1 = [] #儲存每次交叉驗證的f1

    rand = rd.randint(1, 10) #產生交叉驗證抽樣隨機種子
    skf = StratifiedKFold(n_splits=10, random_state = rand, shuffle=True)

    for train_index, test_index in skf.split(x_, y_):
        #print("TRAIN:", train_index, "TEST:", test_index,'\n')
        x_train, x_test = x_.iloc[train_index], x_.iloc[test_index]
        y_train, y_test = y_.iloc[train_index], y_.iloc[test_index]

        x_train = pd.DataFrame(x_train)
        y_train = pd.DataFrame(y_train)

        x_test = pd.DataFrame(x_test)
        y_test = pd.DataFrame(y_test)   



#         clf = AdaBoostClassifier(base_estimator=GaussianNB(), n_estimators=100, random_state=0, algorithm='SAMME.R')
#         clf = GaussianNB()
#         clf = AdaBoostClassifierZe(base_estimator=GaussianNB(), n_estimators=100, random_state=0, algorithm='SAMME.R', fs_enable=fsMethod)
        clf = AdaBoostClassifierZe(base_estimator=SVC(probability=True), n_estimators=100, random_state=0, algorithm='SAMME.R', fs_enable=fsMethod)
#         clf = AdaBoostClassifierZe(n_estimators=100, random_state=0, algorithm='SAMME.R', fs_enable=fsMethod)
#         clf = AdaBoostClassifier(n_estimators=100, random_state=0, algorithm='SAMME.R')

        clf.fit(x_train, y_train)

        ans_f1.append(get_f1(clf,x_test,y_test)) #取得用測試資料測試的f1
        ans_auc.append(get_auc(clf,x_test,y_test)) #取得用測試資料測試的AUC

    #一個方法的十折交叉驗證平均
    AUC.append(np.mean(ans_auc))
    f1.append(np.mean(ans_f1))
#     print('ans_auc : ', ans_auc)
#     print('ans_f1 : ', ans_f1)
        
    print("==========", fsMethod, "==========")
    print(AUC)
    print(f1)
    print("==================================")
    print("")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:16:54 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:16:54 INFO feature select success!
# After select attr:  [70, 43, 14, 38, 10, 8, 46, 40, 35, 82, 27, 62, 12, 74, 31, 61, 65, 80, 33, 68, 55, 7, 5, 26, 25, 11, 13, 1, 30, 21, 22, 28, 4, 2, 29, 18, 19]
# Number of features selected:  37
# After select attr:  [47, 56, 53, 66, 15, 84, 24, 75, 9, 85, 77, 42, 64, 6, 51, 69, 58, 16, 45, 63, 78, 50, 81, 37, 57, 70, 43, 14, 38, 10, 8, 46, 40, 35, 82, 27, 62, 12, 74, 31, 61, 65, 80, 33, 68, 55, 7, 5, 26, 25, 11, 13, 1, 30, 21, 22, 28, 4, 2, 29, 18, 19]
# Number of features selected:  62
# X1
# 弱分類器輸入資料維度 :  37
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:16:56 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:16:56 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.04444444444444445
# SAMME.R弱分類器權重: 3.068052935133617
# 抄出來的若分類器錯誤率： 0.04444444444444445 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  [26, 48, 62, 13, 11, 37, 59, 74, 80, 55, 76, 3, 75, 56, 14, 54, 73, 84, 39, 4, 2, 46, 44, 71, 15, 0, 35, 33, 21, 22, 57, 66, 51, 58, 32, 49, 47, 5, 7, 69, 31, 68, 43, 30, 24, 1, 78, 77, 42, 6, 53, 10, 8, 18, 19]
# Number of features selected:  55
# After select attr:  [52, 82, 65, 41, 45, 40, 9, 28, 27, 38, 16, 29, 12, 81, 83, 36, 26, 48, 62, 13, 11, 37, 59, 74, 80, 55, 76, 3, 75, 56, 14, 54, 73, 84, 39, 4, 2, 46, 44, 71, 15, 0, 35, 33, 21, 22, 57, 66, 51, 58, 32, 49, 47, 5, 7, 69, 31, 68, 43, 30, 24, 1, 78, 77, 42, 6, 53, 10, 8, 18, 19]
# Number of features selected:  71
# X1
# 弱分類器輸入資料維度 :  55
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:17
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:19:48 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.17232084195308187
# SAMME.R弱分類器權重: 1.569267489628008
# 抄出來的若分類器錯誤率： 0.17232084195308187 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  [1, 67, 25, 85, 52, 76, 50, 54, 80, 72, 63, 6, 79, 33, 70, 59, 45, 35, 65, 56, 11, 13, 48, 18, 19, 62, 10, 8, 28, 82, 3, 27, 61, 74, 24]
# Number of features selected:  35
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:19:49 INFO feature select success!
# After select attr:  [9, 44, 4, 2, 53, 69, 75, 43, 16, 77, 15, 29, 38, 78, 0, 30, 73, 68, 26, 39, 32, 81, 42, 64, 66, 1, 67, 25, 85, 52, 76, 50, 54, 80, 72, 63, 6, 79, 33, 70, 59, 45, 35, 65, 56, 11, 13, 48, 18, 19, 62, 10, 8, 28, 82, 3, 27, 61, 74, 24]
# Number of features selected:  60
# X1
# 弱分類器輸入資料維度 :  35
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:19:56 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:19:56 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.22547257280363714
# SAMME.R弱分類器權重: 1.2340545488274919
# 抄出來的若分類器錯誤率： 0.22547257280363714 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  [33, 60, 57, 70, 31, 83, 72, 50, 65, 49, 7, 5, 12, 24, 37, 25, 58, 4, 2, 79, 74, 35, 21, 22, 67, 1, 30, 6, 41, 11, 13, 85, 68, 62, 26, 53]
# Number of features selected:  36
# After select attr:  [47, 52, 36, 73, 75, 64, 59, 3, 63, 18, 19, 66, 28, 27, 56, 8, 10, 15, 80, 39, 77, 29, 61, 45, 32, 16, 33, 60, 57, 70, 31, 83, 72, 50, 65, 49, 7, 5, 12, 24, 37, 25, 58, 4, 2, 79, 74, 35, 21, 22, 67, 1, 30, 6, 41, 11, 13, 85, 68, 62, 26, 53]
# Number of features selected:  62
# X1
# 弱分類器輸入資料維度 :  36
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:20:03 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:20:03 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.23688367979199337
# SAMME.R弱分類器權重: 1.169841252702783
# 抄出來的若分類器錯誤率： 0.23688367979199337 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  [76, 47, 65, 14, 50, 40, 85, 51, 70, 60, 68, 71, 54, 15, 75, 0, 38, 83, 53, 41, 57, 21, 22, 1, 8, 10, 74, 58, 69, 59, 3, 16, 28, 13, 11, 29, 27, 18, 19]
# Number of features selected:  39
# After select attr:  [64, 79, 42, 46, 7, 5, 35, 36, 52, 84, 82, 81, 12, 45, 63, 72, 32, 33, 61, 80, 73, 77, 25, 76, 47, 65, 14, 50, 40, 85, 51, 70, 60, 68, 71, 54, 15, 75, 0, 38, 83, 53, 41, 57, 21, 22, 1, 8, 10, 74, 58, 69, 59, 3, 16, 28, 13, 11, 29, 27, 18, 19]
# Number of features selected:  62
# X1
# 弱分類器輸入資料維度 :  39
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:20:16 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:20:16 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.2332081430014844
# SAMME.R弱分類器權重: 1.1902840192577449
# 抄出來的若分類器錯誤率： 0.2332081430014844 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:21:31 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:21:31 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.20784644793471116
# SAMME.R弱分類器權重: 1.3379556759012108
# 抄出來的若分類器錯誤率： 0.20784644793471116 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  [47, 40, 45, 44, 70, 56, 75, 38, 8, 10, 32, 51, 12, 83, 81, 77, 33, 25, 4, 2, 74, 24, 3, 41, 5, 7, 18, 19, 6, 13, 11, 36, 14, 68, 65, 28, 82, 29, 15, 26, 78, 27]
# Number of features selected:  42
# After select attr:  [60, 61, 69, 43, 57, 37, 1, 71, 52, 72, 76, 39, 85, 58, 30, 0, 64, 16, 84, 66, 9, 48, 67, 31, 53, 46, 49, 47, 40, 45, 44, 70, 56, 75, 38, 8, 10, 32, 51, 12, 83, 81, 77, 33, 25, 4, 2, 74, 24, 3, 41, 5, 7, 18, 19, 6, 13, 11, 36, 14, 68, 65, 28, 82, 29, 15, 26, 78, 27]
# Number of features selected:  69
# X1
# 弱分類器輸入資料維度 :  42
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:21:38 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:21:38 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.17089611239953742
# SAMME.R弱分類器權重: 1.5792896219971835
# 抄出來的若分類器錯誤率： 0.17089611239953742 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  [47, 2, 4, 44, 63, 82, 52, 37, 1, 70, 32, 12, 78, 45, 6, 16, 79, 35, 60, 54, 51, 67, 38, 55, 18, 19, 62, 53, 75, 73, 61, 77, 46, 29, 30, 81, 10, 8, 25, 14, 76, 11, 13, 15]
# Number of features selected:  44
# After select attr:  [48, 36, 57, 68, 74, 64, 41, 27, 85, 72, 69, 40, 9, 49, 56, 33, 21, 22, 3, 71, 39, 0, 28, 47, 2, 4, 44, 63, 82, 52, 37, 1, 70, 32, 12, 78, 45, 6, 16, 79, 35, 60, 54, 51, 67, 38, 55, 18, 19, 62, 53, 75, 73, 61, 77, 46, 29, 30, 81, 10, 8, 25, 14, 76, 11, 13, 15]
# Number of features selected:  67
# X1
# 弱分類器輸入資料維度 :  44
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:21:45 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 15:21:45 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.2164714671576693
# SAMME.R弱分類器權重: 1.2863487309520079
# 抄出來的若分類器錯誤率： 0.2164714671576693 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  [72, 80, 85, 14, 84, 48, 82, 81, 68, 12, 62, 71, 33, 6, 39, 2, 4, 66, 77, 25, 78, 16, 18, 19, 1, 70, 43, 8, 10, 31, 60, 15, 59, 28, 21, 22, 50, 0, 26]
# Number of features selected:  39
# After select attr:  [63, 67, 35, 9, 57, 47, 24, 49, 76, 42, 83, 32, 58, 73, 40, 69, 37, 56, 36, 41, 72, 80, 85, 14, 84, 48, 82, 81, 68, 12, 62, 71, 33, 6, 39, 2, 4, 66, 77, 25, 78, 16, 18, 19, 1, 70, 43, 8, 10, 31, 60, 15, 59, 28, 21, 22, 50, 0, 26]
# Number of features selected:  59
# X1
# 弱分類器輸入資料維度 :  39
# ...
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 17:23:43 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 17:23:43 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.22269794678394528
# SAMME.R弱分類器權重: 1.250012663133695
# 抄出來的若分類器錯誤率： 0.22269794678394528 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 17:24:13 INFO feature select success!
# /opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:3709: F_onewayConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(F_onewayConstantInputWarning())
# 2021 17:24:13 INFO feature select success!
# SAMME.R弱分類器錯誤率: 0.16556075291411068
# SAMME.R弱分類器權重: 1.6174217243255395
# 抄出來的若分類器錯誤率： 0.16556075291411068 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# After select attr:  [75, 11, 72, 65, 83, 4, 2, 74, 57, 51, 14, 54, 69, 10, 56, 8, 42, 61, 64, 33, 1, 47, 21, 22, 26, 52, 16, 58, 0, 3, 9, 6, 84, 59, 30, 28, 18, 19]
# Number of features selected:  38
# After select attr:  [50, 71, 45, 49, 48, 15, 37, 43, 82, 29, 31, 35, 38, 80, 77, 25, 44, 53, 39, 62, 78, 55, 13, 75, 11, 72, 65, 83, 4, 2, 74, 57, 51, 14, 54, 69, 10, 56, 8, 42, 61, 64, 33, 1, 47, 21, 22, 26, 52, 16, 58, 0, 3, 9, 6, 84, 59, 30, 28, 18, 19]
# Number of features selected:  61
# X1
# 弱分類器輸入資料維度 :  38
# SAMME.R弱分類器錯誤率: 0.20603402998112036
# SAMME.R弱分類器權重: 1.348999252180729
# 抄出來的若分類器錯誤率： 0.20603402998112036 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.7154471544715447
#
# 這次的AUC :  0.8005351456055682
#
# ========== anova_kf ==========
# [0.8226213239757294]
# [0.7394094681105402]
# ==================================
#
# 重要屬性index: [2, 4, 12, 11, 18, 7, 29, 28, 5, 1, 10, 22, 13, 3, 30, 0, 8]
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SAMME.R弱分類器錯誤率: 0.053555555555555565
# SAMME.R弱分類器權重: 2.871992736432558
# 抄出來的若分類器錯誤率： 0.053555555555555565 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [2, 9, 0, 6, 7, 10, 11, 13, 12, 3, 4, 28, 8, 5, 1, 31, 18]
# SAMME.R弱分類器錯誤率: 0.1570370964269775
# SAMME.R弱分類器權重: 1.6804408913698783
# 抄出來的若分類器錯誤率： 0.1570370964269775 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [9, 5, 0, 3, 12, 7, 6, 4, 10, 11, 2, 25, 19, 13, 8, 26, 24]
# SAMME.R弱分類器錯誤率: 0.19089919071972347
# SAMME.R弱分類器權重: 1.4441780276024223
# 抄出來的若分類器錯誤率： 0.19089919071972347 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [0, 9, 6, 3, 12, 2, 4, 13, 8, 10, 5, 7, 11, 25, 1, 26, 78]
# SAMME.R弱分類器錯誤率: 0.24137671984407316
# SAMME.R弱分類器權重: 1.14514645118031
# 抄出來的若分類器錯誤率： 0.24137671984407316 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [12, 13, 0, 8, 2, 7, 5, 3, 4, 6, 9, 10, 30, 11, 29, 28, 56]
# SAMME.R弱分類器錯誤率: 0.26570627763409904
# SAMME.R弱分類器權重: 1.016517636018617
# 抄出來的若分類器錯誤率： 0.26570627763409904 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [7, 3, 2, 9, 12, 10, 6, 0, 5, 4, 19, 8, 13, 1, 11, 21, 78]
# SAMME.R弱分類器錯誤率: 0.2666520586225353
# SAMME.R弱分類器權重: 1.0116756132062377
# 抄出來的若分類器錯誤率： 0.2666520586225353 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [4, 11, 6, 12, 3, 0, 7, 5, 9, 8, 13, 10, 27, 2, 39, 18, 67]
# SAMME.R弱分類器錯誤率: 0.27340309873987007
# SAMME.R弱分類器權重: 0.9774245967514374
# 抄出來的若分類器錯誤率： 0.27340309873987007 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [5, 9, 6, 7, 4, 18, 2, 0, 12, 11, 10, 13, 8, 3, 28, 14, 31]
# SAMME.R弱分類器錯誤率: 0.2677161819962394
# SAMME.R弱分類器權重: 1.0062407713786636
# 抄出來的若分類器錯誤率： 0.2677161819962394 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [0, 9, 5, 2, 12, 8, 11, 6, 3, 10, 13, 29, 4, 7, 28, 1, 18]
# SAMME.R弱分類器錯誤率: 0.29370240336761716
# SAMME.R弱分類器權重: 0.8774696524106435
# 抄出來的若分類器錯誤率： 0.29370240336761716 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [6, 3, 9, 4, 0, 5, 2, 7, 12, 13, 18, 10, 11, 24, 38, 29, 26]
# SAMME.R弱分類器錯誤率: 0.29580199626478626
# SAMME.R弱分類器權重: 0.8673692729672355
# 抄出來的若分類器錯誤率： 0.29580199626478626 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [8, 2, 7, 6, 3, 5, 9, 0, 4, 12, 11, 10, 1, 18, 70, 24, 21]
# SAMME.R弱分類器錯誤率: 0.27621439016469507
# SAMME.R弱分類器權重: 0.9633178893799303
# 抄出來的若分類器錯誤率： 0.27621439016469507 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [0, 4, 7, 3, 9, 5, 6, 13, 12, 2, 11, 8, 79, 1, 16, 26, 25]
# SAMME.R弱分類器錯誤率: 0.22820645367455458
# SAMME.R弱分類器權重: 1.2184663694096811
# 抄出來的若分類器錯誤率： 0.22820645367455458 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [13, 0, 9, 6, 12, 8, 3, 7, 11, 4, 2, 10, 75, 19, 25, 28, 30]
# SAMME.R弱分類器錯誤率: 0.2361602911975262
# SAMME.R弱分類器權重: 1.1738471874587566
# 抄出來的若分類器錯誤率： 0.2361602911975262 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [18, 3, 9, 2, 12, 8, 11, 0, 6, 5, 10, 13, 4, 7, 38, 29, 53]
# SAMME.R弱分類器錯誤率: 0.2822468726495897
# SAMME.R弱分類器權重: 0.9333435532539632
# 抄出來的若分類器錯誤率： 0.2822468726495897 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [10, 3, 9, 2, 7, 0, 11, 8, 6, 13, 5, 4, 12, 29, 1, 28, 51]
# SAMME.R弱分類器錯誤率: 0.28433692596554516
# SAMME.R弱分類器權重: 0.9230495951912467
# 抄出來的若分類器錯誤率： 0.28433692596554516 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [11, 3, 19, 2, 12, 7, 9, 5, 0, 4, 6, 8, 10, 13, 25, 57, 70]
# SAMME.R弱分類器錯誤率: 0.28912303479004303
# SAMME.R弱分類器權重: 0.8996470466835735
# 抄出來的若分類器錯誤率： 0.28912303479004303 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [3, 0, 9, 7, 5, 12, 4, 2, 11, 13, 6, 19, 28, 29, 1, 18, 30]
# SAMME.R弱分類器錯誤率: 0.29384421894244167
# SAMME.R弱分類器權重: 0.8767861068424169
# 抄出來的若分類器錯誤率： 0.29384421894244167 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [0, 6, 9, 3, 4, 2, 19, 12, 7, 11, 5, 8, 18, 28, 13, 10, 29]
# SAMME.R弱分類器錯誤率: 0.3021794468757315
# SAMME.R弱分類器權重: 0.8369409466315731
# 抄出來的若分類器錯誤率： 0.3021794468757315 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [9, 0, 3, 6, 8, 5, 11, 4, 10, 12, 7, 13, 2, 26, 18, 78, 28]
# SAMME.R弱分類器錯誤率: 0.2842089945092635
# SAMME.R弱分類器權重: 0.9236783688974637
# 抄出來的若分類器錯誤率： 0.2842089945092635 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [6, 5, 11, 7, 0, 9, 10, 3, 2, 13, 4, 8, 12, 28, 57, 39, 31]
# SAMME.R弱分類器錯誤率: 0.28964457090464146
# SAMME.R弱分類器權重: 0.8971108954076041
# 抄出來的若分類器錯誤率： 0.28964457090464146 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [8, 0, 3, 9, 10, 5, 2, 13, 11, 4, 6, 12, 7, 29, 28, 18, 30]
# SAMME.R弱分類器錯誤率: 0.3183688018344125
# SAMME.R弱分類器權重: 0.7612782814430955
# 抄出來的若分類器錯誤率： 0.3183688018344125 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [7, 3, 0, 2, 9, 12, 5, 6, 10, 4, 11, 18, 8, 29, 13, 28, 14]
# SAMME.R弱分類器錯誤率: 0.29128294199793864
# SAMME.R弱分類器權重: 0.8891612708960632
# 抄出來的若分類器錯誤率： 0.29128294199793864 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [9, 0, 3, 13, 6, 2, 10, 18, 12, 5, 7, 11, 8, 25, 56, 4, 83]
# SAMME.R弱分類器錯誤率: 0.2904228425763357
# SAMME.R弱分類器權重: 0.8933313008322555
# 抄出來的若分類器錯誤率： 0.2904228425763357 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [5, 0, 4, 10, 11, 7, 9, 8, 3, 2, 13, 6, 26, 16, 1, 12, 56]
# SAMME.R弱分類器錯誤率: 0.25892406453973293
# SAMME.R弱分類器權重: 1.0515682654435687
# 抄出來的若分類器錯誤率： 0.25892406453973293 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [3, 2, 6, 8, 0, 5, 4, 10, 7, 11, 12, 1, 9, 81, 13, 15, 28]
# SAMME.R弱分類器錯誤率: 0.28226377262027513
# SAMME.R弱分類器權重: 0.9332601325538342
# 抄出來的若分類器錯誤率： 0.28226377262027513 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [13, 0, 12, 6, 2, 4, 3, 10, 5, 9, 7, 11, 8, 19, 24, 15, 28]
# SAMME.R弱分類器錯誤率: 0.2520911849685912
# SAMME.R弱分類器權重: 1.0874901983305054
# 抄出來的若分類器錯誤率： 0.2520911849685912 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [5, 0, 6, 9, 4, 2, 12, 3, 7, 1, 8, 13, 11, 29, 10, 25, 28]
# SAMME.R弱分類器錯誤率: 0.2901109259207897
# SAMME.R弱分類器權重: 0.8948453711183874
# 抄出來的若分類器錯誤率： 0.2901109259207897 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [0, 3, 6, 9, 7, 10, 2, 4, 8, 11, 13, 12, 74, 5, 70, 18, 64]
# SAMME.R弱分類器錯誤率: 0.2827400507832124
# SAMME.R弱分類器權重: 0.9309103990528561
# 抄出來的若分類器錯誤率： 0.2827400507832124 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [9, 5, 0, 3, 7, 2, 6, 13, 10, 11, 8, 12, 4, 29, 61, 57, 41]
# SAMME.R弱分類器錯誤率: 0.29475662882190723
# SAMME.R弱分類器權重: 0.8723929217803877
# 抄出來的若分類器錯誤率： 0.29475662882190723 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [5, 3, 0, 9, 12, 4, 2, 10, 11, 8, 13, 6, 18, 7, 78, 15, 31]
# SAMME.R弱分類器錯誤率: 0.3119893982843054
# SAMME.R弱分類器權重: 0.7908350399109471
# 抄出來的若分類器錯誤率： 0.3119893982843054 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [7, 5, 9, 3, 0, 18, 1, 4, 8, 6, 11, 12, 10, 13, 2, 79, 28]
# SAMME.R弱分類器錯誤率: 0.2951023806739115
# SAMME.R弱分類器權重: 0.8707302221899313
# 抄出來的若分類器錯誤率： 0.2951023806739115 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [9, 0, 2, 6, 3, 7, 13, 4, 12, 11, 10, 5, 8, 18, 15, 56, 29]
# SAMME.R弱分類器錯誤率: 0.3054169682377682
# SAMME.R弱分類器權重: 0.8216337592801939
# 抄出來的若分類器錯誤率： 0.3054169682377682 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [3, 2, 7, 4, 19, 0, 5, 9, 6, 11, 12, 13, 8, 15, 79, 10, 18]
# SAMME.R弱分類器錯誤率: 0.3019980656048029
# SAMME.R弱分類器權重: 0.83780126202611
# 抄出來的若分類器錯誤率： 0.3019980656048029 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [4, 2, 12, 5, 10, 13, 11, 6, 9, 3, 8, 0, 7, 29, 30, 50, 24]
# SAMME.R弱分類器錯誤率: 0.30557682472248676
# SAMME.R弱分類器權重: 0.8208803182402677
# 抄出來的若分類器錯誤率： 0.30557682472248676 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [0, 5, 9, 6, 4, 10, 7, 2, 8, 11, 3, 12, 13, 28, 53, 83, 31]
# SAMME.R弱分類器錯誤率: 0.3199386056475454
# SAMME.R弱分類器權重: 0.7540539598716914
# 抄出來的若分類器錯誤率： 0.3199386056475454 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [2, 12, 0, 13, 7, 9, 6, 3, 8, 11, 4, 10, 1, 5, 30, 63, 50]
# SAMME.R弱分類器錯誤率: 0.2961297645630445
# SAMME.R弱分類器權重: 0.8657962624531024
# 抄出來的若分類器錯誤率： 0.2961297645630445 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 重要屬性index: [6, 18, 0, 8, 12, 13, 11, 7, 3, 9, 4, 10, 2, 19, 5, 26, 72]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-61d740159e89> in <module>
#      48 #         clf = AdaBoostClassifier(n_estimators=100, random_state=0, algorithm='SAMME.R')
#      49
# ---> 50         clf.fit(x_train, y_train)
#      51
#      52         ans_f1.append(get_f1(clf,x_test,y_test)) #取得用測試資料測試的f1
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_weight_boosting.py in fit(self, X, y, sample_weight)
#     988
#     989         # Fit
# --> 990         return super().fit(X, y, sample_weight)
#     991
#     992     def _validate_estimator(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_weight_boosting.py in fit(self, X, y, sample_weight)
#     129         for iboost in range(self.n_estimators):
#     130             # Boosting step
# --> 131             sample_weight, estimator_weight, estimator_error = self._boost(
#     132                 iboost,
#     133                 X, y,
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#    1011
#    1012         if self.algorithm == 'SAMME.R':
# -> 1013             return self._boost_real(iboost, X, y, sample_weight, random_state)
#    1014
#    1015         else:  # elif self.algorithm == "SAMME":
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_weight_boosting.py in _boost_real(self, iboost, X, y, sample_weight, random_state)
#    1200         #estimator.fit(X, y, sample_weight=sample_weight)
#    1201         #把抽樣拿到外面做
# -> 1202         estimator.fit(X, y)
#    1203
#    1204         #y_predict_proba = estimator.predict_proba(X)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     224
#     225         seed = rnd.randint(np.iinfo('i').max)
# --> 226         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     227         # see comment on the other call to np.iinfo in this file
#     228
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     275         self.support_, self.support_vectors_, self._n_support, \
#     276             self.dual_coef_, self.intercept_, self._probA, \
# --> 277             self._probB, self.fit_status_ = libsvm.fit(
#     278                 X, y,
#     279                 svm_type=solver_type, sample_weight=sample_weight,
#
# KeyboardInterrupt:
