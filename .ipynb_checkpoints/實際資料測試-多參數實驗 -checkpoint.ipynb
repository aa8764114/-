# %% [markdown]
# ## churn.all

# %% [markdown]
# import pandas as pd
#
# #放在不同資料夾用絕對路徑
# data = pd.read_csv('./data/churn.all.csv')
#
# #刪除不要的欄位
# data.drop(['id'], inplace=True, axis=1)
# data.drop(['phone_number'], inplace=True, axis=1)
#
# #將目標屬性轉為數字
# import numpy as np
# data['Churn'] = np.where(data['Churn'] == ' False', 0, 1)
#
# #分割輸入屬性及目標屬性
#
# #輸入屬性
# x_ = data.drop(['Churn'], axis=1)#同上方法刪除行
#
# #目標屬性
# y_ = data['Churn']
#
# #去除錯誤值及空值填補
# from sklearn.pipeline import Pipeline
# from data_preprocessing_pipeline import *
# from feature_engineering import *
#
# pipe = Pipeline(
#        [
#         ('define_column_type', define_column_type()),
#         ('scaler', scaler()),
#         ('dummies', dummies()),
#         #('filter', feature_selection(method = 'anova_kf', p_threshold = 1)),
#         #('sfs',feature_selection(method = 'sfs', sfs_direction = direction, sfs_scoring = scoring, sfs_cv = cv, sfs_estimator = estimator))
#        ])
#
# x_ = pipe.fit_transform(x_, y_)
# print(x_.shape)

# %% [markdown]
# ## bank

# %% [markdown]
# import pandas as pd
#
# #放在不同資料夾用絕對路徑
# data = pd.read_csv('bank.csv')
#
# #刪除ID
# #data.drop(['id'], inplace=True, axis=1)
#
# #將目標屬性轉為數字
# import numpy as np
# data['y'] = np.where(data['y'] == 'no', 0, 1)
#
# #分割輸入屬性及目標屬性
#
# #輸入屬性
# x_ = data.drop(['y'], axis=1)#同上方法刪除行
# #x_ = data.drop(['phone_number'], axis=1)#同上方法刪除行
#
# #目標屬性
# y_ = data['y']
#
# #去除錯誤值及空值填補
# from sklearn.pipeline import Pipeline
# from data_preprocessing_pipeline import *
# from feature_engineering import *
#
# pipe = Pipeline(
#        [
#         ('Wrong_Value',wrong_value_fillna(wrong_value=['unknown'])),
#         ('Null_Value', xgb_fill()),
#         ('define_column_type', define_column_type()),
#         ('scaler', scaler()),
#         ('dummies', dummies()),
#        ])
#
# x_ = pipe.fit_transform(x_, y_)
# print(x_.shape)

# %% [markdown]
# ## WPBC

# %% [markdown]
# import pandas as pd
#
# #放在不同資料夾用絕對路徑
# wpbc = pd.read_csv('wpbc.csv', header=None)
#
# #刪除ID
# wpbc.drop([0], inplace=True, axis=1)
#
# #將目標屬性轉為數字
# import numpy as np
# wpbc[1] = np.where(wpbc[1] == 'N', 0, 1)
#
# #分割輸入屬性及目標屬性
#
# #輸入屬性
# x_ = wpbc.drop([1], axis=1)#同上方法刪除行
#
# #目標屬性
# y_ = wpbc[1]
#
# #去除錯誤值及空值填補
# from sklearn.pipeline import Pipeline
# from data_preprocessing_pipeline import *
# from feature_engineering import *
#
# pipe = Pipeline(
#        [
#          ('Wrong_Value',wrong_value_fillna(wrong_value=['?'])),
#          ('column_type', define_column_type()),
#          #('Outlier', fix_outlier(how='quartile')),
#
#          ('Null_Value', xgb_fill()),
#          #('num_log', num_log()),
#
#          ('Wrong_Value2',wrong_value_fillna(wrong_value=[np.nan, float('-inf')])),
#          ('Null_Value2', xgb_fill()),
#
#        ])
#
# x_ = pipe.fit_transform(x_, y_)
# print(x_.shape)

# %% [markdown]
# ## 用產生資料測試

# %% [markdown]
# from sklearn.datasets import make_classification
# import pandas as pd
#
# x_, y_ = make_classification(n_samples=5000, n_features=100,
#                              n_informative=60, n_redundant=20,
#                              n_classes=2, random_state=0, shuffle=True)
#
# x_ = pd.DataFrame(x_)
# y_ = pd.DataFrame(y_)

# %% [markdown]
# ## 2.Statlog (Australian Credit Approval)

# %% [markdown]
# import pandas as pd
#
# #放在不同資料夾用絕對路徑
# data = pd.read_csv('./data/2.Statlog (Australian Credit Approval).csv', header=None)
#
# #輸入屬性
# x_ = data.drop([14], axis=1)#同上方法刪除行
#
# #目標屬性
# y_ = data[14]
#
# #去除錯誤值及空值填補
# from sklearn.pipeline import Pipeline
# from data_preprocessing_pipeline import *
# from feature_engineering import *
#
# pipe = Pipeline(
#        [
#         ('define_column_type', define_column_type()),
#         ('scaler', scaler()),
#        ])
#
# x_ = pipe.fit_transform(x_, y_)
# print(x_.shape)

# %% [markdown]
# ## 6.default of credit card clients

# %%
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/6.default of credit card clients.csv')

#輸入屬性
x_ = data.drop(['default payment next month'], axis=1)#同上方法刪除行

#目標屬性
y_ = data['default payment next month']

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
#         ('scaler', scaler()),
         ('dummies', dummies()),
#         ('filter', feature_selection(method = 'anova_kf', p_threshold = 1)),
#         ('sfs',feature_selection(method = 'sfs', sfs_direction = direction, sfs_scoring = scoring, sfs_cv = cv, sfs_estimator = estimator))
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)
# Out:
# 2021 11:17:44 INFO Fit Columns Type Already Success!!!
# 2021 11:17:44 INFO Transform Columns Type Success!!!
# 2021 11:17:44 INFO dummies Success!!!
# (30000, 57)

# %% [markdown]
# ## 將index轉換為欄位名稱

# %%
def index_to_colname(indexs, oridata):
    colname = []
    for i in indexs:
        colname.append(list(x_.columns)[i])
    
    return(colname)

# %% [markdown]
# ## 輸入模型將屬性重要性轉為index輸出

# %%
def importance_to_index(clf, prob):
    importances = list(clf.feature_importances_)
    s = importances
    s2 = sorted(range(len(s)), key=lambda k: s[k], reverse=True)
    return s2[:int(len(s2)*prob)]

# %% [markdown]
# ## 交叉驗證AUC

# %%
#計算AUC函數
def get_auc(model, x, y):
    
    '''
    model : 用甚麼方式建模
    x : 輸入屬性
    y : 目標屬性
    '''
    import numpy as np
    from sklearn import metrics
    
    #建模
    #model.fit(x, y)

    #用訓練資料測試
    fpr, tpr, thresholds = metrics.roc_curve(y, model.predict(x))
    auc = metrics.auc(fpr, tpr)

    print('這次的AUC : ', auc,'\n')
    return auc

# %%
#計算f1函數
def get_f1(model, x, y):
    
    '''
    model : 用甚麼方式建模
    x : 輸入屬性
    y : 目標屬性
    '''
    import numpy as np
    from sklearn.metrics import f1_score
    
    #建模
    #model.fit(x, y)

    #用訓練資料測試
    f1 = f1_score(y, model.predict(x), average='binary')

    print('這次的f1 : ', f1,'\n')
    return f1

# %%
from sklearn.ensemble import AdaBoostClassifierZe
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import numpy as np


#交叉驗證，分層隨機抽樣
from sklearn.model_selection import StratifiedKFold
import random as rd



# fs_method = ['anova_kf', 'gini', 'entropy', 'rf_gini', 'rf_entropy', 'xgb', False]
fs_method = ['xgb', False]



for fsMethod in fs_method:
    
    f1 = [] #存不同方法的交叉驗證平均f1
    AUC = [] #存不同方法的交叉驗證平均AUC
    
    ans_auc = [] #儲存每次交叉驗證的AUC
    ans_f1 = [] #儲存每次交叉驗證的f1

    rand = rd.randint(1, 10) #產生交叉驗證抽樣隨機種子
    skf = StratifiedKFold(n_splits=10, random_state = rand, shuffle=True)

    for train_index, test_index in skf.split(x_, y_):
        #print("TRAIN:", train_index, "TEST:", test_index,'\n')
        x_train, x_test = x_.iloc[train_index], x_.iloc[test_index]
        y_train, y_test = y_.iloc[train_index], y_.iloc[test_index]

        x_train = pd.DataFrame(x_train)
        y_train = pd.DataFrame(y_train)

        x_test = pd.DataFrame(x_test)
        y_test = pd.DataFrame(y_test)   



#         clf = AdaBoostClassifier(base_estimator=GaussianNB(), n_estimators=100, random_state=0, algorithm='SAMME')
#         clf = GaussianNB()
#         clf = AdaBoostClassifierZe(base_estimator=GaussianNB(), n_estimators=100, random_state=0, algorithm='SAMME.R', fs_enable=fsMethod)
#         clf = AdaBoostClassifierZe(base_estimator=SVC(probability=True), n_estimators=100, random_state=0, algorithm='SAMME.R', fs_enable=fsMethod)
#         clf = AdaBoostClassifierZe(n_estimators=100, random_state=0, algorithm='SAMME.R', fs_enable=fsMethod)
        clf = AdaBoostClassifier(n_estimators=100, random_state=0, algorithm='SAMME.R')

        clf.fit(x_train, y_train)

        ans_f1.append(get_f1(clf,x_test,y_test)) #取得用測試資料測試的f1
        ans_auc.append(get_auc(clf,x_test,y_test)) #取得用測試資料測試的AUC

    #一個方法的十折交叉驗證平均
    AUC.append(np.mean(ans_auc))
    f1.append(np.mean(ans_f1))
    print('ans_auc : ', ans_auc)
    print('ans_f1 : ', ans_f1)
        
    print("==========", fsMethod, "==========")
    print(AUC)
    print(f1)
    print("==================================")
    print("")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4484848484848485
#
# 這次的AUC :  0.6449084007261925
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.44948453608247424
#
# 這次的AUC :  0.645321010067668
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.44623115577889444
#
# 這次的AUC :  0.6438381952467404
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4477611940298507
#
# 這次的AUC :  0.6445989437200857
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4373056994818653
#
# 這次的AUC :  0.6396218435385377
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4457953394123607
#
# 這次的AUC :  0.6436164177256974
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4426719840478564
#
# 這次的AUC :  0.6421747725455343
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.44238683127572015
#
# 這次的AUC :  0.6420305260447222
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4539007092198581
#
# 這次的AUC :  0.6475341593139675
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4122448979591836
#
# 這次的AUC :  0.627733664809856
#
# ans_auc :  [0.6449084007261925, 0.645321010067668, 0.6438381952467404, 0.6445989437200857, 0.6396218435385377, 0.6436164177256974, 0.6421747725455343, 0.6420305260447222, 0.6475341593139675, 0.627733664809856]
# ans_f1 :  [0.4484848484848485, 0.44948453608247424, 0.44623115577889444, 0.4477611940298507, 0.4373056994818653, 0.4457953394123607, 0.4426719840478564, 0.44238683127572015, 0.4539007092198581, 0.4122448979591836]
# ========== xgb ==========
# [0.6421377933739001]
# [0.44262671957729116]
# ==================================
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.43668993020937186
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的AUC :  0.6392247070473674
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.45954045954045947
#
# 這次的AUC :  0.6502903738240633
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# ...
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.42544316996871745
#
# 這次的AUC :  0.6341627991178697
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.44855967078189296
#
# 這次的AUC :  0.6449348180073846
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4369918699186992
#
# 這次的AUC :  0.6394631319497286
#
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 抄出來的若分類器錯誤率： 0 資料有幾類： 2
# 亂猜的錯誤率： 0.5
# 這次的f1 :  0.4521384928716904
#
# 這次的AUC :  0.6466677122117731
#
# ans_auc :  [0.6392247070473674, 0.6502903738240633, 0.6448052483908235, 0.6474691574517247, 0.6327570556197393, 0.6396527892391484, 0.6341627991178697, 0.6449348180073846, 0.6394631319497286, 0.6466677122117731]
# ans_f1 :  [0.43668993020937186, 0.45954045954045947, 0.44824120603015083, 0.4540763673890609, 0.42288049029622066, 0.43756243756243757, 0.42544316996871745, 0.44855967078189296, 0.4369918699186992, 0.4521384928716904]
# ========== False ==========
# [0.6419427792859622]
# [0.4422124094568701]
# ==================================
