# %% [markdown]
# ## churn.all

# %%
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/churn.all.csv')

#刪除不要的欄位
data.drop(['id'], inplace=True, axis=1)
data.drop(['phone_number'], inplace=True, axis=1)

#將目標屬性轉為數字
import numpy as np
data['Churn'] = np.where(data['Churn'] == ' False', 0, 1)

#分割輸入屬性及目標屬性

#輸入屬性
x_ = data.drop(['Churn'], axis=1)#同上方法刪除行

#目標屬性
y_ = data['Churn']

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
        ('scaler', scaler()),
        ('dummies', dummies()),
        #('filter', feature_selection(method = 'anova_kf', p_threshold = 1)),
        #('sfs',feature_selection(method = 'sfs', sfs_direction = direction, sfs_scoring = scoring, sfs_cv = cv, sfs_estimator = estimator))
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)

# %% [markdown]
# ## bank

# %%
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/bank.csv')

#刪除ID
#data.drop(['id'], inplace=True, axis=1)

#將目標屬性轉為數字
import numpy as np
data['y'] = np.where(data['y'] == 'no', 0, 1)

#分割輸入屬性及目標屬性

#輸入屬性
x_ = data.drop(['y'], axis=1)#同上方法刪除行
#x_ = data.drop(['phone_number'], axis=1)#同上方法刪除行

#目標屬性
y_ = data['y']

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
#         ('Wrong_Value',wrong_value_fillna(wrong_value=['unknown'])),
#         ('Null_Value', xgb_fill()),
        ('define_column_type', define_column_type()),
        ('scaler', scaler()),
        ('dummies', dummies()),
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)

# %% [markdown]
# ## WPBC

# %%
import pandas as pd

#放在不同資料夾用絕對路徑
wpbc = pd.read_csv('./data/wpbc.csv', header=None)

#刪除ID
wpbc.drop([0], inplace=True, axis=1)

#將目標屬性轉為數字
import numpy as np
wpbc[1] = np.where(wpbc[1] == 'N', 0, 1)

#分割輸入屬性及目標屬性

#輸入屬性
x_ = wpbc.drop([1], axis=1)#同上方法刪除行

#目標屬性
y_ = wpbc[1]

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
         ('Wrong_Value',wrong_value_fillna(wrong_value=['?'])),
         ('column_type', define_column_type()),
         #('Outlier', fix_outlier(how='quartile')), 
         
         ('Null_Value', xgb_fill()),
         #('num_log', num_log()),
         
         ('Wrong_Value2',wrong_value_fillna(wrong_value=[np.nan, float('-inf')])),
         ('Null_Value2', xgb_fill()),
  
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)

# %% [markdown]
# ## 2.Statlog (Australian Credit Approval)

# %%
#澳大利亞信貸審批，沒說目標屬性哪個是通過不通過
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/2.australian.csv', header=None)

#輸入屬性
x_ = data.drop([14], axis=1)#同上方法刪除行

#目標屬性
y_ = data[14]

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
        ('scaler', scaler()),
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)

# %% [markdown]
# ## 6.default of credit card clients

# %%
#客戶信用卡資料，下個月是否付款
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/6.default of credit card clients.csv')

#輸入屬性
x_ = data.drop(['default payment next month'], axis=1)#同上方法刪除行

#目標屬性
y_ = data['default payment next month']

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
        ('scaler', scaler()),
        ('dummies', dummies()),
        #('filter', feature_selection(method = 'anova_kf', p_threshold = 1)),
        #('sfs',feature_selection(method = 'sfs', sfs_direction = direction, sfs_scoring = scoring, sfs_cv = cv, sfs_estimator = estimator))
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)
# Out:
# 2021 18:40:17 INFO Fit Columns Type Already Success!!!
# 2021 18:40:17 INFO Transform Columns Type Success!!!
# 2021 18:40:17 INFO scaler Success!!!
# 2021 18:40:18 INFO dummies Success!!!
# (30000, 57)
# Counter({0: 23364, 1: 6636})

# %% [markdown]
# ## 9.hepatitis

# %%
#病人資訊（肝炎）->是否死
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/9.hepatitis.csv', header=None)

#將目標屬性轉為數字
import numpy as np
data[0] = np.where(data[0] == 2, 0, 1)

#輸入屬性
x_ = data.drop([0], axis=1)#同上方法刪除行

#目標屬性
y_ = data[0]

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('Wrong_Value',wrong_value_fillna(wrong_value=['?'])),
        ('filter', feature_selection(method = 'var')),
        ('Null_Value', xgb_fill()),
        ('define_column_type', define_column_type()),
#         ('dummies', dummies()),
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)
# Out:
# 2021 16:06:32 INFO Wrong Values has Filled as np.nan!!!
# 2021 16:06:32 INFO feature select success!
# 0it [00:00, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# After select attr:  [16, 15, 18, 1, 14, 17]
# Number of features selected:  6
# 100%|██████████| 6/6 [00:01<00:00,  5.37it/s]
# 2021 16:06:34 INFO xgb_fill Fit Success!!!
# 0it [00:00, ?it/s]
# 100%|██████████| 6/6 [00:00<00:00, 135.70it/s]
# 2021 16:06:34 INFO xgb_fill for NA Success!!!
# 2021 16:06:34 INFO Fit Columns Type Already Success!!!
# 2021 16:06:34 INFO Transform Columns Type Success!!!
# (155, 6)
# Counter({0: 123, 1: 32})

# %% [markdown]
# ## 11.ionosphere

# %%
#電離層的雷達回波分類好壞
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/11.ionosphere.csv', header=None)

#刪除不要的欄位
data.drop([0], inplace=True, axis=1)

#將目標屬性轉為數字
import numpy as np
data[34] = np.where(data[34] == 'g', 1, 0)

#輸入屬性
x_ = data.drop([34], axis=1)#同上方法刪除行

#目標屬性
y_ = data[34]

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
#         ('dummies', dummies()),
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)
# Out:
# 2021 15:50:55 INFO Fit Columns Type Already Success!!!
# 2021 15:50:55 INFO Transform Columns Type Success!!!
# (351, 33)
# Counter({1: 225, 0: 126})

# %% [markdown]
# ## 16.sonar

# %%
#分類聲納訊號掃到的是岩石（Ｒ）或金屬圓柱（Ｍ）
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/16.sonar.csv', header=None)

#將目標屬性轉為數字
import numpy as np
data[60] = np.where(data[60] == 'R', 0, 1)

#輸入屬性
x_ = data.drop([60], axis=1)#同上方法刪除行

#目標屬性
y_ = data[60]

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
#         ('dummies', dummies()),
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)
# Out:
# 2021 15:29:40 INFO Fit Columns Type Already Success!!!
# 2021 15:29:40 INFO Transform Columns Type Success!!!
# (208, 60)
# Counter({1: 111, 0: 97})

# %% [markdown]
# ## 17.tic-tac-toe

# %%
#井字遊戲，positive (i.e., wins for "x")
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/17.tic-tac-toe.csv', header=None)

#將目標屬性轉為數字
import numpy as np
data[9] = np.where(data[9] == 'negative', 0, 1)

#輸入屬性
x_ = data.drop([9], axis=1)#同上方法刪除行

#目標屬性
y_ = data[9]

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
        ('dummies', dummies()),
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)
# Out:
# 2021 15:02:06 INFO Fit Columns Type Already Success!!!
# 2021 15:02:06 INFO Transform Columns Type Success!!!
# 2021 15:02:06 INFO dummies Success!!!
# (958, 36)
# Counter({1: 626, 0: 332})

# %% [markdown]
# ## 21.broadband

# %%
#電信客戶流失
import pandas as pd

#放在不同資料夾用絕對路徑
data = pd.read_csv('./data/21.broadband.csv')

#刪除不要的欄位
data.drop(['CUST_ID'], inplace=True, axis=1)

#輸入屬性
x_ = data.drop(['BROADBAND'], axis=1)#同上方法刪除行

#目標屬性
y_ = data['BROADBAND']

#去除錯誤值及空值填補
from sklearn.pipeline import Pipeline
from data_preprocessing_pipeline import *
from feature_engineering import *

pipe = Pipeline(
       [
        ('define_column_type', define_column_type()),
        ('dummies', dummies()),
       ])

x_ = pipe.fit_transform(x_, y_)
print(x_.shape)

import collections
c = collections.Counter(y_)
print(c)
# Out:
# 2021 14:29:21 INFO Fit Columns Type Already Success!!!
# 2021 14:29:21 INFO Transform Columns Type Success!!!
# 2021 14:29:21 INFO dummies Success!!!
# (1114, 19)
# Counter({0: 908, 1: 206})

# %% [markdown]
# ## 用產生資料測試

# %%
from sklearn.datasets import make_classification
import pandas as pd

x_, y_ = make_classification(n_samples=5000, n_features=100,
                             n_informative=80, n_redundant=20,
                             n_classes=2, random_state=0, shuffle=True)

x_ = pd.DataFrame(x_)
y_ = pd.DataFrame(y_)

# %% [markdown]
# ## 將index轉換為欄位名稱

# %%
def index_to_colname(indexs, oridata):
    colname = []
    for i in indexs:
        colname.append(list(x_.columns)[i])
    
    return(colname)

# %% [markdown]
# ## 輸入模型將屬性重要性轉為index輸出

# %%
def importance_to_index(feature_importances_, prob):
    importances = list(feature_importances_)
    s = importances
    s2 = sorted(range(len(s)), key=lambda k: s[k], reverse=True)
    return s2[:int(len(s2)*prob)]

# %% [markdown]
# ## 交叉驗證AUC

# %%
#計算AUC函數
def get_auc(model, x, y):
    
    '''
    model : 用甚麼方式建模
    x : 輸入屬性
    y : 目標屬性
    '''
    import numpy as np
    from sklearn import metrics
    
    #建模
    #model.fit(x, y)

    #用訓練資料測試
    fpr, tpr, thresholds = metrics.roc_curve(y, model.predict(x))
    auc = metrics.auc(fpr, tpr)

    print('這次的AUC : ', auc,'\n')
    return auc

# %%
#計算f1函數
def get_f1(model, x, y):
    
    '''
    model : 用甚麼方式建模
    x : 輸入屬性
    y : 目標屬性
    '''
    import numpy as np
    from sklearn.metrics import f1_score
    
    #建模
    #model.fit(x, y)

    #用訓練資料測試
    f1 = f1_score(y, model.predict(x), average='binary')

    print('這次的f1 : ', f1,'\n')
    return f1

# %%
from sklearn.ensemble import AdaBoostClassifierZe
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import numpy as np


#交叉驗證，分層隨機抽樣
from sklearn.model_selection import StratifiedKFold
import random as rd


#'corr', 'var'：測試階段
# fs_method = ['anova_kf', 'gini', 'entropy', 'rf_gini', 'rf_entropy', 'xgb', 'corr', 'var', False]
fs_method = ['entropy', 'gini', 'rf_entropy', 'rf_gini', 'xgb']
# fs_method = ['anova_kf']




for fsMethod in fs_method:
    
    f1 = [] #存不同方法的交叉驗證平均f1
    AUC = [] #存不同方法的交叉驗證平均AUC
    
    ans_auc = [] #儲存每次交叉驗證的AUC
    ans_f1 = [] #儲存每次交叉驗證的f1

    rand = rd.randint(1, 10) #產生交叉驗證抽樣隨機種子
    skf = StratifiedKFold(n_splits=10, random_state = rand, shuffle=True)

    for train_index, test_index in skf.split(x_, y_):
        #print("TRAIN:", train_index, "TEST:", test_index,'\n')
        x_train, x_test = x_.iloc[train_index], x_.iloc[test_index]
        y_train, y_test = y_.iloc[train_index], y_.iloc[test_index]

        x_train = pd.DataFrame(x_train)
        y_train = pd.DataFrame(y_train)

        x_test = pd.DataFrame(x_test)
        y_test = pd.DataFrame(y_test)   


        #選擇建模方法
        clf = AdaBoostClassifierZe(base_estimator=GaussianNB(), n_estimators=100, random_state=0, algorithm='SAMME', fs_enable=fsMethod, fs_mode=1)

        clf.fit(x_train, y_train)
        features = importance_to_index(clf.get_my_feature_importance(), 0.6)
        clf2 = GaussianNB()
        clf2.fit(x_train[index_to_colname(features, x_train)], y_train)


        ans_f1.append(get_f1(clf2,x_test[index_to_colname(features, x_train)], y_test)) #取得用測試資料測試的f1
        ans_auc.append(get_auc(clf2,x_test[index_to_colname(features, x_train)], y_test)) #取得用測試資料測試的AUC

    #一個方法的十折交叉驗證平均
    AUC.append(np.mean(ans_auc))
    f1.append(np.mean(ans_f1))
    print('ans_auc : ', ans_auc)
    print('ans_f1 : ', ans_f1)
        
    print("==========", fsMethod, "==========")
    print(AUC)
#     print(f1)
    print("==================================")
    print("")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 重要屬性index: [3, 0, 7, 2, 15, 1, 12, 8, 18, 14, 13, 9, 17, 16, 11, 10, 5, 6, 24, 39, 4, 25, 21, 40, 20, 30, 47, 41, 50, 48, 29, 27, 49, 28, 22, 46, 32, 31, 43, 19, 36, 52, 23, 26, 33, 34, 35, 37, 38, 42, 44, 45, 51, 53, 54, 55, 56]
# 弱分類器錯誤率: 0.2014074074074074
# SAMME弱分類器權重: 1.3775211599066473
# 重要屬性index: [0, 2, 7, 3, 14, 15, 1, 8, 18, 10, 11, 16, 17, 9, 13, 12, 48, 4, 39, 41, 40, 6, 25, 30, 5, 21, 27, 20, 28, 24, 49, 29, 47, 46, 22, 43, 50, 42, 32, 33, 31, 44, 19, 23, 26, 34, 35, 36, 37, 38, 45, 51, 52, 53, 54, 55, 56]
# 弱分類器錯誤率: 0.5064160540288225
# SAMME弱分類器權重: -0.025665624903393212
# 重要屬性index: [0, 7, 3, 2, 1, 14, 18, 17, 8, 10, 15, 12, 16, 13, 11, 9, 48, 40, 4, 5, 6, 39, 25, 30, 20, 41, 21, 29, 24, 47, 28, 49, 22, 46, 27, 31, 50, 51, 43, 42, 32, 19, 23, 26, 33, 34, 35, 36, 37, 38, 44, 45, 52, 53, 54, 55, 56]
# 弱分類器錯誤率: 0.5064668829836924
# SAMME弱分類器權重: -0.025868974472989432
# 重要屬性index: [0, 3, 7, 2, 14, 13, 1, 18, 11, 12, 15, 9, 10, 8, 16, 17, 48, 40, 6, 5, 30, 39, 41, 4, 24, 20, 25, 21, 49, 29, 28, 27, 47, 46, 22, 43, 50, 32, 31, 51, 52, 33, 19, 23, 26, 34, 35, 36, 37, 38, 42, 44, 45, 53, 54, 55, 56]
# 弱分類器錯誤率: 0.5056024525199583
# SAMME弱分類器權重: -0.022410748000269664
# 重要屬性index: [0, 3, 7, 2, 1, 14, 13, 18, 9, 16, 10, 17, 8, 15, 12, 11, 48, 5, 6, 40, 39, 30, 4, 41, 21, 24, 28, 20, 25, 27, 29, 22, 47, 50, 43, 31, 46, 49, 19, 23, 26, 32, 33, 34, 35, 36, 37, 38, 42, 44, 45, 51, 52, 53, 54, 55, 56]
# 弱分類器錯誤率: 0.4967889629296185
# SAMME弱分類器權重: 0.012844324863120126
# 重要屬性index: [0, 3, 7, 1, 2, 14, 18, 12, 13, 8, 15, 17, 16, 10, 9, 11, 48, 6, 4, 5, 40, 41, 39, 30, 25, 21, 24, 20, 29, 28, 49, 47, 22, 27, 43, 46, 44, 32, 31, 34, 50, 19, 23, 26, 33, 35, 36, 37, 38, 42, 45, 51, 52, 53, 54, 55, 56]
# 弱分類器錯誤率: 0.
WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 重要屬性index: [3, 27, 5, 30, 29, 4, 49, 46, 28, 7, 42, 1, 16, 9, 8, 21, 50, 15, 6, 13, 14, 10, 39, 11, 18, 17, 48, 19, 31, 0, 12, 43, 47, 20, 2, 22, 24, 40, 41, 51, 52, 32, 23, 25, 26, 33, 34, 35, 36, 37, 38, 44, 45, 53, 54, 55, 56]
# 弱分類器錯誤率: 0.5024759578292841
# SAMME弱分類器權重: -0.009903912270490731
# [11:28:32] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 重要屬性index: [4, 30, 3, 5, 46, 27, 48, 49, 29, 6, 47, 7, 28, 22, 8, 39, 42, 13, 1, 15, 14, 11, 12, 18, 32, 16, 10, 41, 17, 9, 0, 2, 21, 24, 31, 43, 40, 35, 20, 51, 33, 50, 19, 23, 25, 26, 34, 36, 37, 38, 44, 45, 52, 53, 54, 55, 56]
# 弱分類器錯誤率: 0.4986870647214495
# SAMME弱分類器權重: 0.005251753184847008
# 這次的f1 :  0.5024691358024691
#
# 這次的AUC :  0.6892659305254639
#
# ans_auc :  [0.6836627331242779, 0.6742629765637893, 0.678525746822908, 0.6846117346096716, 0.6794618542663806, 0.69435963030203, 0.6699214098594903, 0.6861370399843556, 0.6839665657909257, 0.6892659305254639]
# ans_f1 :  [0.4932313125367863, 0.495253164556962, 0.49851632047477745, 0.5042016806722689, 0.5015243902439025, 0.5138339920948616, 0.4845814977973568, 0.49875930521091805, 0.5035360678925036, 0.5024691358024691]
# ========== xgb ==========
# [0.6824175621849293]
# ==================================
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
from sklearn.ensemble import AdaBoostClassifierZe
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import numpy as np
from sklearn.tree import DecisionTreeClassifier


#交叉驗證，分層隨機抽樣
from sklearn.model_selection import StratifiedKFold
import random as rd

ans_auc = [] #儲存每次交叉驗證的AUC
ans_f1 = [] #儲存每次交叉驗證的f1

rand = rd.randint(1, 10) #產生交叉驗證抽樣隨機種子
skf = StratifiedKFold(n_splits=10, random_state = rand, shuffle=True)

for train_index, test_index in skf.split(x_, y_):
    #print("TRAIN:", train_index, "TEST:", test_index,'\n')
    x_train, x_test = x_.iloc[train_index], x_.iloc[test_index]
    y_train, y_test = y_.iloc[train_index], y_.iloc[test_index]

    x_train = pd.DataFrame(x_train)
    y_train = pd.DataFrame(y_train)

    x_test = pd.DataFrame(x_test)
    y_test = pd.DataFrame(y_test)   


    #選擇建模方法
    clf = AdaBoostClassifier(n_estimators=100, algorithm='SAMME', random_state=0)
    clf.fit(x_train, y_train)
    
    importance = clf.feature_importances_
    features = importance_to_index(importance, 0.6)
    clf2 = GaussianNB()
    clf2.fit(x_train[index_to_colname(features, x_train)], y_train)

    ans_f1.append(get_f1(clf2,x_test[index_to_colname(features, x_train)], y_test)) #取得用測試資料測試的f1
    ans_auc.append(get_auc(clf2,x_test[index_to_colname(features, x_train)], y_test)) #取得用測試資料測試的AUC

#一個方法的十折交叉驗證平均
print('ans_auc : ', np.mean(ans_auc))
# print('ans_f1 : ', np.mean(ans_f1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SAMME弱分類器權重: 0.7819901994230375
#
# SAMME弱分類器權重: 0.3352663298343335
#
# SAMME弱分類器權重: 0.20068374285239307
#
# SAMME弱分類器權重: 0.06289212780070964
#
# SAMME弱分類器權重: 0.04245233690399181
#
# SAMME弱分類器權重: 0.030681269145034887
#
# SAMME弱分類器權重: 0.02372506422999511
#
# SAMME弱分類器權重: 0.018526061117198723
#
# SAMME弱分類器權重: 0.014847144330296819
#
# SAMME弱分類器權重: 0.012136120476838687
#
# SAMME弱分類器權重: 0.010076833655020972
#
# SAMME弱分類器權重: 0.00847450533523018
#
# SAMME弱分類器權重: 0.007208421093814005
#
# SAMME弱分類器權重: 0.006184515547243455
#
# SAMME弱分類器權重: 0.005344322469115269
#
# SAMME弱分類器權重: 0.0046526912021833365
#
# SAMME弱分類器權重: 0.004068405324035483
#
# SAMME弱分類器權重: 0.0035804013894613195
#
# SAMME弱分類器權重: 0.003159935792178865
#
# SAMME弱分類器權重: 0.0028011185888454967
#
# SAMME弱分類器權重: 0.0024914166964406185
#
# SAMME弱分類器權重: 0.0022234694745780774
#
# SAMME弱分類器權重: 0.0019869903295548596
#
# SAMME弱分類器權重: 0.0017837228471942683
#
# SAMME弱分類器權重: 0.0016007998352602767
#
# SAMME弱分類器權重: 0.0014407526555943312
#
# SAMME弱分類器權重: 0.0012988799883692133
#
# SAMME弱分類器權重: 0.0011707770432875747
#
# SAMME弱分類器權重: 0.001059432538323665
#
# SAMME弱分類器權重: 0.00096069885885766
#
# SAMME弱分類器權重: 0.0008706139546756192
#
# SAMME弱分類器權重: 0.0007888841942867367
#
# SAMME弱分類器權重: 0.0007152542912461744
#
# SAMME弱分類器權重: 0.0006495032278693138
#
# SAMME弱分類器權重: 0.0005914404355264875
#
# SAMME弱分類器權重: 0.0005374348698757285
#
# SAMME弱分類器權重: 0.0004908448036197869
#
# SAMME弱分類器權重: 0.00044809826656491415
#
# SAMME弱分類器權重: 0.00040568566906267487
#
# SAMME弱分類器權重: 0.00037043570405555687
#
# SAMME弱分類器權重: 0.000338837980232878
#
# SAMME弱分類器權重: 0.00031084495387034817
#
# SAMME弱分類器權重: 0.00028300567816930144
#
# SAMME弱分類器權重: 0.0002587106810820855
#
# SAMME弱分類器權重: 0.00023452762652570016
#
# SAMME弱分類器權重: 0.00021384054567835049
#
# SAMME弱分類器權重: 0.00019662280260260314
#
# SAMME弱分類器權重: 0.00017946563604237777
#
# SAMME弱分類器權重: 0.00016574644239246867
#
# SAMME弱分類器權重: 0.0001486887252018728
#
# SAMME弱分類器權重: 0.0001384298022327745
#
# SAMME弱分類器權重: 0.00012482274683689213
#
# SAMME弱分類器權重: 0.00011461770740890015
#
# SAMME弱分類器權重: 0.00010443382168634789
#
# SAMME弱分類器權重: 9.763601352276416e-05
#
# SAMME弱分類器權重: 8.74853249944731e-05
#
# SAMME弱分類器權重: 8.071398864718594e-05
#
# SAMME弱分類器權重: 7.395255969285349e-05
#
# SAMME弱分類器權重: 6.720022750832147e-05
#
# SAMME弱分類器權重: 6.381486015608393e-05
#
# SAMME弱分類器權重: 5.707596231550654e-05
#
# SAMME弱分類器權重: 5.0344141018750663e-05
#
# SAMME弱分類器權重: 4.6973867804667995e-05
#
# SAMME弱分類器權重: 4.3606464236621816e-05
#
# SAMME弱分類器權重: 4.0241728858259964e-05
#
# SAMME弱分類器權重: 3.687946048271288e-05
#
# SAMME弱分類器權重: 3.351945817128771e-05
#
# SAMME弱分類器權重: 3.0161521211051493e-05
#
# SAMME弱分類器權重: 2.68054491006288e-05
#
# SAMME弱分類器權重: 2.6801190319765366e-05
#
# SAMME弱分類器權重: 2.34473156789262e-05
#
# SAMME弱分類器權重: 2.3444056070828537e-05
#
# SAMME弱分類器權重: 2.0092111636494313e-05
#
# SAMME弱分類器權重: 1.674143123200688e-05
#
# SAMME弱分類器權重: 1.6739768818097097e-05
#
# SAMME弱分類器權重: 1.67381065673846e-05
#
# SAMME弱分類器權重: 1.3389155583620833e-05
#
# SAMME弱分類器權重: 1.338809195091321e-05
#
# SAMME弱分類器權重: 1.3387028401025986e-05
#
# SAMME弱分類器權重: 1.0039473701709086e-05
#
# SAMME弱分類器權重: 1.0038875550412592e-05
#
# SAMME弱分類器權重: 1.0038277432422099e-05
#
# SAMME弱分類器權重: 6.691786233397652e-06
#
# SAMME弱分類器權重: 6.691520435349692e-06
#
# SAMME弱分類器權重: 6.691254646405431e-06
#
# SAMME弱分類器權重: 6.690988868563255e-06
#
# SAMME弱分類器權重: 6.690723101379078e-06
#
# SAMME弱分類器權重: 6.690457344408814e-06
#
# SAMME弱分類器權重: 3.345095798597944e-06
#
# SAMME弱分類器權重: 3.345029363740513e-06
#
# SAMME弱分類器權重: 3.3449629315476047e-06
#
# SAMME弱分類器權重: 3.3448965002428667e-06
#
# SAMME弱分類器權重: 3.3448300698263004e-06
#
# SAMME弱分類器權重: 3.3447636411860803e-06
#
# SAMME弱分類器權重: 3.344697213434031e-06
#
# SAMME弱分類器權重: 3.3446307872362846e-06
#
# SAMME弱分類器權重: 3.3445643628148845e-06
#
# SAMME弱分類器權重: 3.3444979395036993e-06
#
# SAMME弱分類器權重: 3.3444315157484224e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.4870790916209867
#
# 這次的AUC :  0.6695463360290478
#
# SAMME弱分類器權重: 0.7821973473110913
#
# SAMME弱分類器權重: 0.333339333289905
#
# SAMME弱分類器權重: 0.19931665915749497
#
# SAMME弱分類器權重: 0.1457039935246228
#
# SAMME弱分類器權重: 0.07934267671095914
#
# SAMME弱分類器權重: 0.050591287228772076
#
# SAMME弱分類器權重: 0.033587991218148996
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.485512920908379
#
# 這次的AUC :  0.6685792828849645
#
# SAMME弱分類器權重: 0.7803335907366884
#
# SAMME弱分類器權重: 0.33213358491649064
#
# SAMME弱分類器權重: 0.19847376477229978
#
# SAMME弱分類器權重: 0.06226413537672255
#
# SAMME弱分類器權重: 0.04211795686979714
#
# SAMME弱分類器權重: 0.03049041699263439
#
# SAMME弱分類器權重: 0.023096686507162838
#
# SAMME弱分類器權重: 0.018090279261223877
#
# SAMME弱分類器權重: 0.014520472296611481
#
# SAMME弱分類器權重: 0.011885121385245142
#
# SAMME弱分類器權重: 0.009877527613463766
#
# SAMME弱分類器權重: 0.00831827412555025
#
# SAMME弱分類器權重: 0.007075345162576751
#
# SAMME弱分類器權重: 0.006071341013358495
#
# SAMME弱分類器權重: 0.005248620863755309
#
# SAMME弱分類器權重: 0.004568414071018221
#
# SAMME弱分類器權重: 0.003998540414389378
#
# SAMME弱分類器權重: 0.0035157361992966055
#
# SAMME弱分類器權重: 0.0031039851096085385
#
# SAMME弱分類器權重: 0.002753353484658103
#
# SAMME弱分類器權重: 0.0024475351856833106
#
# SAMME弱分類器權重: 0.00218328415324505
#
# SAMME弱分類器權重: 0.0019503322757927742
#
# SAMME弱分類器權重: 0.001746750743175029
#
# SAMME弱分類器權重: 0.0015709208630821003
#
# SAMME弱分類器權重: 0.001410439973539447
#
# SAMME弱分類器權重: 0.0012718144646672515
#
# SAMME弱分類器權重: 0.0011468947467506202
#
# SAMME弱分類器權重: 0.0010387190739508346
#
# SAMME弱分類器權重: 0.0009395469188307563
#
# SAMME弱分類器權重: 0.000849045055690861
#
# SAMME弱分類器權重: 0.0007704736228339961
#
# SAMME弱分類器權重: 0.0006999856533078784
#
# SAMME弱分類器權重: 0.000633850247840576
#
# SAMME弱分類器權重: 0.0005754450265494005
#
# SAMME弱分類器權重: 0.0005246085737464712
#
# SAMME弱分類器權重: 0.0004777160241759228
#
# SAMME弱分類器權重: 0.0004346870445409877
#
# SAMME弱分類器權重: 0.00039545096924442126
#
# SAMME弱分類器權重: 0.0003599459209361028
#
# SAMME弱分類器權重: 0.00032811796638593113
#
# SAMME弱分類器權重: 0.0002999203027017201
#
# SAMME弱分類器權重: 0.0002753124694673191
#
# SAMME弱分類器權重: 0.0002508236424876046
#
# SAMME弱分類器權重: 0.0002264434123078287
#
# SAMME弱分類器權重: 0.0002090143770899017
#
# SAMME弱分類器權重: 0.00018822735501598963
#
# SAMME弱分類器權重: 0.0001743475047328777
#
# SAMME弱分類器權重: 0.00015709538273410626
#
# SAMME弱分類器權重: 0.00014330391552842066
#
# SAMME弱分類器權重: 0.00013295695709857852
#
# SAMME弱分類器權重: 0.00012263446465610262
#
# SAMME弱分類器權重: 0.00011233457377056886
#
# SAMME弱分類器權重: 0.00010205542684775461
#
# SAMME弱分類器權重: 9.17951725817736e-05
#
# SAMME弱分類器權重: 8.494996397049112e-05
#
# SAMME弱分類器權重: 7.811517172144179e-05
#
# SAMME弱分類器權重: 7.128997613311569e-05
#
# SAMME弱分類器權重: 6.447355944385445e-05
#
# SAMME弱分類器權重: 5.766510566258271e-05
#
# SAMME弱分類器權重: 5.4254720443222237e-05
#
# SAMME弱分類器權重: 5.084764093090891e-05
#
# SAMME弱分類器權重: 4.405483000282366e-05
#
# SAMME弱分類器權重: 4.065549963594186e-05
#
# SAMME弱分類器權重: 3.725866127247046e-05
#
# SAMME弱分類器權重: 3.386411193555315e-05
#
# SAMME弱分類器權重: 3.0471648882031047e-05
#
# SAMME弱分類器權重: 3.0466203274345557e-05
#
# SAMME弱分類器權重: 2.707622988875851e-05
#
# SAMME弱分類器權重: 2.3687937616032712e-05
#
# SAMME弱分類器權重: 2.368464503698671e-05
#
# SAMME弱分類器權重: 2.029830249277655e-05
#
# SAMME弱分類器權重: 2.0295884118179483e-05
#
# SAMME弱分類器權重: 1.6911221688664507e-05
#
# SAMME弱分類器權重: 1.690954265661159e-05
#
# SAMME弱分類器權重: 1.3526291030488343e-05
#
# SAMME弱分類器權重: 1.3525216660660846e-05
#
# SAMME弱分類器權重: 1.3524142373431671e-05
#
# SAMME弱分類器權重: 1.0142301128715915e-05
#
# SAMME弱分類器權重: 1.0141696937484842e-05
#
# SAMME弱分類器權重: 1.014109278178018e-05
#
# SAMME弱分類器權重: 6.760325775623836e-06
#
# SAMME弱分類器權重: 6.7600572930929685e-06
#
# SAMME弱分類器權重: 6.759788820331926e-06
#
# SAMME弱分類器權重: 6.759520360005225e-06
#
# SAMME弱分類器權重: 6.759251908782219e-06
#
# SAMME弱分類器權重: 6.758983469327426e-06
#
# SAMME弱分類器權重: 3.3793575192149786e-06
#
# SAMME弱分類器權重: 3.379290415563734e-06
#
# SAMME弱分類器權重: 3.379223311912485e-06
#
# SAMME弱分類器權重: 3.3791562091494073e-06
#
# SAMME弱分類器權重: 3.379089109050851e-06
#
# SAMME弱分類器權重: 3.3790220089522903e-06
#
# SAMME弱分類器權重: 3.3789549106300755e-06
#
# SAMME弱分類器權重: 3.378887814084208e-06
#
# SAMME弱分類器權重: 3.3788207184265105e-06
#
# SAMME弱分類器權重: 3.3787536236569843e-06
#
# SAMME弱分類器權重: 3.3786865304417603e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.5027322404371585
#
# 這次的AUC :  0.6793277562304011
#
# SAMME弱分類器權重: 0.7834664769836616
#
# SAMME弱分類器權重: 0.33483855670093926
#
# SAMME弱分類器權重: 0.20004381664833432
#
# SAMME弱分類器權重: 0.05539684302739111
#
# SAMME弱分類器權重: 0.038058718318554584
#
# SAMME弱分類器權重: 0.027773973851078472
#
# SAMME弱分類器權重: 0.021120715997932114
#
# SAMME弱分類器權重: 0.016552624507242854
#
# SAMME弱分類器權重: 0.013268756729487487
#
# SAMME弱分類器權重: 0.010828689744485106
#
# SAMME弱分類器權重: 0.00895961966827552
#
# SAMME弱分類器權重: 0.007506274244309702
#
# SAMME弱分類器權重: 0.006343005713694443
#
# SAMME弱分類器權重: 0.005407440473246783
#
# SAMME弱分類器權重: 0.004639488842393687
#
# SAMME弱分類器權重: 0.004002666950384416
#
# SAMME弱分類器權重: 0.003470639103005458
#
# SAMME弱分類器權重: 0.00302075221032448
#
# SAMME弱分類器權重: 0.002637614258697869
#
# SAMME弱分類器權重: 0.0023120880561581145
#
# SAMME弱分類器權重: 0.002036168753364265
#
# SAMME弱分類器權重: 0.0017939657225779944
#
# SAMME弱分類器權重: 0.0015836812361997297
#
# SAMME弱分類器權重: 0.0013995085494104345
#
# SAMME弱分類器權重: 0.0012403315921011072
#
# SAMME弱分類器權重: 0.0011009587604425125
#
# SAMME弱分類器權重: 0.0009807132896694464
#
# SAMME弱分類器權重: 0.0008705802438820252
#
# SAMME弱分類器權重: 0.0007744375253562383
#
# SAMME弱分類器權重: 0.0006919409747807883
#
# SAMME弱分類器權重: 0.000618624374593817
#
# SAMME弱分類器權重: 0.0005501306732992321
#
# SAMME弱分類器權重: 0.0004946560004679904
#
# SAMME弱分類器權重: 0.00043958057556063666
#
# SAMME弱分類器權重: 0.0003931374773181343
#
# SAMME弱分類器權重: 0.0003510933903370334
#
# SAMME弱分類器權重: 0.00031751437784797667
#
# SAMME弱分類器權重: 0.0002840923502337542
#
# SAMME弱分類器權重: 0.00025492283957021536
#
# SAMME弱分類器權重: 0.00022586377251964353
#
# SAMME弱分類器權重: 0.00020510721641746302
#
# SAMME弱分類器權重: 0.00018031575237759033
#
# SAMME弱分類器權重: 0.00016378067139303338
#
# SAMME弱分類器權重: 0.00014728591673711792
#
# SAMME弱分類器權重: 0.0001308275372779343
#
# SAMME弱分類器權重: 0.00011848736784804124
#
# SAMME弱分類器權重: 0.00010616908294859274
#
# SAMME弱分類器權重: 9.387047504995567e-05
#
# SAMME弱分類器權重: 8.566880969969443e-05
#
# SAMME弱分類器權重: 7.747765975064485e-05
#
# SAMME弱分類器權重: 6.929604787066264e-05
#
# SAMME弱分類器權重: 6.112299864675276e-05
#
# SAMME弱分類器權重: 5.7031195186410407e-05
#
# SAMME弱分類器權重: 4.887033602151298e-05
#
# SAMME弱分類器權重: 4.4787167966499104e-05
#
# SAMME弱分類器權重: 4.070674259548648e-05
#
# SAMME弱分類器權重: 3.662881699069788e-05
#
# SAMME弱分類器權重: 3.2553148484606194e-05
#
# SAMME弱分類器權重: 2.847949463907369e-05
#
# SAMME弱分類器權重: 2.4407613216052787e-05
#
# SAMME弱分類器權重: 2.4404714590848034e-05
#
# SAMME弱分類器權重: 2.0334846918980464e-05
#
# SAMME弱分類器權重: 2.0332834454184388e-05
#
# SAMME弱分類器權重: 1.6264657746332842e-05
#
# SAMME弱分類器權重: 1.6263370019812398e-05
#
# SAMME弱分類器權重: 1.2196561793550622e-05
#
# SAMME弱分類器權重: 1.2195837558163444e-05
#
# SAMME弱分類器權重: 1.2195113365851868e-05
#
# SAMME弱分類器權重: 8.12959281016172e-06
#
# SAMME弱分類器權重: 8.129270985102367e-06
#
# SAMME弱分類器權重: 8.128949171811177e-06
#
# SAMME弱分類器權重: 8.128627370288152e-06
#
# SAMME弱分類器權重: 8.128305582975762e-06
#
# SAMME弱分類器權重: 4.0639919030373935e-06
#
# SAMME弱分類器權重: 4.0639114619330095e-06
#
# SAMME弱分類器權重: 4.063831022827012e-06
#
# SAMME弱分類器權重: 4.0637505841650955e-06
#
# SAMME弱分類器權重: 4.063670148833827e-06
#
# SAMME弱分類器權重: 4.063589714390728e-06
#
# SAMME弱分類器權重: 4.063509281057842e-06
#
# SAMME弱分類器權重: 4.063428850389472e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.48204309656823624
#
# 這次的AUC :  0.6659798440336688
#
# SAMME弱分類器權重: 0.784969488728141
#
# SAMME弱分類器權重: 0.3354364424843099
#
# SAMME弱分類器權重: 0.199677274360944
#
# SAMME弱分類器權重: 0.054826464203683714
#
# SAMME弱分類器權重: 0.037716328516476015
#
# SAMME弱分類器權重: 0.02753904067851647
#
# SAMME弱分類器權重: 0.02094915949475398
#
# SAMME弱分類器權重: 0.016416874617573442
#
# SAMME弱分類器權重: 0.013161430147918141
#
# SAMME弱分類器權重: 0.010733850124098162
#
# SAMME弱分類器權重: 0.008880766561689271
#
# SAMME弱分類器權重: 0.007431207891074459
#
# SAMME弱分類器權重: 0.0062814880312889705
#
# SAMME弱分類器權重: 0.005348612444768384
#
# SAMME弱分類器權重: 0.004583273731935055
#
# SAMME弱分類器權重: 0.003953811359279506
#
# SAMME弱分類器權重: 0.003424233476466788
#
# SAMME弱分類器權重: 0.0029768394105758092
#
# SAMME弱分類器權重: 0.002600819405522949
#
# SAMME弱分類器權重: 0.00227783542481245
#
# SAMME弱分類器權重: 0.0020001164209337173
#
# SAMME弱分類器權重: 0.0017607056651895974
#
# SAMME弱分類器權重: 0.0015532854278547837
#
# SAMME弱分類器權重: 0.001372038517155181
#
# SAMME弱分類器權重: 0.0012158814982939756
#
# SAMME弱分類器權重: 0.0010752818950143337
#
# SAMME弱分類器權重: 0.0009539661635886946
#
# SAMME弱分類器權重: 0.0008471003736510223
#
# SAMME弱分類器權重: 0.0007542918206658545
#
# SAMME弱分類器權重: 0.0006709660331440534
#
# SAMME弱分類器權重: 0.00060113596824671
#
# SAMME弱分類器權重: 0.0005361258555452638
#
# SAMME弱分類器權重: 0.00047582718204187095
#
# SAMME弱分類器權重: 0.00042434631725282116
#
# SAMME弱分類器權重: 0.0003815680225760764
#
# SAMME弱分類器權重: 0.0003390261098320287
#
# SAMME弱分類器權重: 0.0003050524817798454
#
# SAMME弱分類器權重: 0.00027122982604055605
#
# SAMME弱分類器權重: 0.00024170925277336937
#
# SAMME弱分類器權重: 0.0002164561949338954
#
# SAMME弱分類器權重: 0.00019544183152784368
#
# SAMME弱分類器權重: 0.00017448774867728417
#
# SAMME弱分類器權重: 0.0001577386864067211
#
# SAMME弱分類器權重: 0.00014102850606435795
#
# SAMME弱分類器權重: 0.00012435320925503388
#
# SAMME弱分類器權重: 0.00011185145825209924
#
# SAMME弱分類器權重: 9.937040527940824e-05
#
# SAMME弱分類器權重: 9.104628342919415e-05
#
# SAMME弱分類器權重: 7.859665372464509e-05
#
# SAMME弱分類器權重: 7.029688457699009e-05
#
# SAMME弱分類器權重: 6.613951903660307e-05
#
# SAMME弱分類器權重: 5.785375780279834e-05
#
# SAMME弱分類器權重: 5.370646505153835e-05
#
# SAMME弱分類器權重: 4.543224254475061e-05
#
# SAMME弱分類器權重: 4.129304908239784e-05
#
# SAMME弱分類器權重: 3.715639061976552e-05
#
# SAMME弱分類器權重: 3.302202106850457e-05
#
# SAMME弱分類器權重: 2.8889694575536268e-05
#
# SAMME弱分類器權重: 2.8885693068099322e-05
#
# SAMME弱分類器權重: 2.475573608863232e-05
#
# SAMME弱分類器權重: 2.0627330837045487e-05
#
# SAMME弱分類器權重: 2.0625290042973244e-05
#
# SAMME弱分類器權重: 1.6498599557477657e-05
#
# SAMME弱分類器權重: 1.6497293702947808e-05
#
# SAMME弱分類器權重: 1.2371990961541e-05
#
# SAMME弱分類器權重: 1.2371256532339175e-05
#
# SAMME弱分類器權重: 1.2370522145546804e-05
#
# SAMME弱分類器權重: 1.2369787801830017e-05
#
# SAMME弱分類器權重: 8.246035666228956e-06
#
# SAMME弱分類器權重: 8.24570932951995e-06
#
# SAMME弱分類器權重: 8.245383005245234e-06
#
# SAMME弱分類器權重: 8.24505669296072e-06
#
# SAMME弱分類器權重: 4.122365196556785e-06
#
# SAMME弱分類器權重: 4.122283624588586e-06
#
# SAMME弱分類器權重: 4.122202055728991e-06
#
# SAMME弱分類器權重: 4.122120486647346e-06
#
# SAMME弱分類器權重: 4.122038920008174e-06
#
# SAMME弱分類器權重: 4.121957354257171e-06
#
# SAMME弱分類器權重: 4.121875790504555e-06
#
# SAMME弱分類器權重: 4.121794228528281e-06
#
# SAMME弱分類器權重: 4.121712667662219e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.48348106365834004
#
# 這次的AUC :  0.6666142308961875
#
# SAMME弱分類器權重: 0.7828965894253913
#
# SAMME弱分類器權重: 0.33501856858419393
#
# SAMME弱分類器權重: 0.20031923271472
#
# SAMME弱分類器權重: 0.0564473205773524
#
# SAMME弱分類器權重: 0.038662378085879356
#
# SAMME弱分類器權重: 0.02816289824092019
#
# SAMME弱分類器權重: 0.02139657480934474
#
# SAMME弱分類器權重: 0.016756027122686038
#
# SAMME弱分類器權重: 0.013426783708747265
#
# SAMME弱分類器權重: 0.010955302000497722
#
# SAMME弱分類器權重: 0.009070539077980786
#
# SAMME弱分類器權重: 0.007593530237853671
#
# SAMME弱分類器權重: 0.00641925276847184
#
# SAMME弱分類器權重: 0.005473757735385031
#
# SAMME弱分類器權重: 0.004696687621673871
#
# SAMME弱分類器權重: 0.0040560351217698845
#
# SAMME弱分類器權重: 0.003515746495843065
#
# SAMME弱分類器權重: 0.0030624940643011653
#
# SAMME弱分類器權重: 0.0026805554902060848
#
# SAMME弱分類器權重: 0.0023516622185342393
#
# SAMME弱分類器權重: 0.002067990263177147
#
# SAMME弱分類器權重: 0.0018225540647691626
#
# SAMME弱分類器權重: 0.0016133414428924856
#
# SAMME弱分類器權重: 0.0014301387825922047
#
# SAMME弱分類器權重: 0.0012675654404483488
#
# SAMME弱分類器權重: 0.0011247833565270146
#
# SAMME弱分類器權重: 0.0010010906345415693
#
# SAMME弱分類器權重: 0.0008917163298427705
#
# SAMME弱分類器權重: 0.0007962449627679137
#
# SAMME弱分類器權重: 0.0007101748283860612
#
# SAMME弱分類器權重: 0.0006332697899793703
#
# SAMME弱分類器權重: 0.0005653288575545127
#
# SAMME弱分類器權重: 0.0005061820741454503
#
# SAMME弱分類器權重: 0.00045158131177500035
#
# SAMME弱分類器權重: 0.0004055384459603206
#
# SAMME弱分類器權重: 0.0003638606628510811
#
# SAMME弱分類器權重: 0.0003264896575896471
#
# SAMME弱分類器權重: 0.0002933754325500701
#
# SAMME弱分類器權重: 0.00026040653245731476
#
# SAMME弱分類器權重: 0.00023569446986416548
#
# SAMME弱分類器權重: 0.00021106968789198072
#
# SAMME弱分類器權重: 0.00019057816090379122
#
# SAMME弱分類器權重: 0.00017014544624172992
#
# SAMME弱分類器權重: 0.00015381313266218697
#
# SAMME弱分類器權重: 0.00013751875383319497
#
# SAMME弱分類器權重: 0.00012125840869251898
#
# SAMME弱分類器權重: 0.00010906775646081396
#
# SAMME弱分類器權重: 0.00010093468537461483
#
# SAMME弱分類器權重: 8.877856408086386e-05
#
# SAMME弱分類器權重: 8.067263536146113e-05
#
# SAMME弱分類器權重: 7.25766248770731e-05
#
# SAMME弱分類器權重: 6.448956681735285e-05
#
# SAMME弱分類器權重: 5.641049716732849e-05
#
# SAMME弱分類器權重: 5.2366657993504334e-05
#
# SAMME弱分類器權重: 4.832601295913348e-05
#
# SAMME弱分類器權重: 4.428832122924593e-05
#
# SAMME弱分類器權重: 3.622800803700631e-05
#
# SAMME弱分類器權重: 3.622155302361634e-05
#
# SAMME弱分類器權重: 3.219119923090628e-05
#
# SAMME弱分類器權重: 2.8162838158973778e-05
#
# SAMME弱分類器權重: 2.4136230208988964e-05
#
# SAMME弱分類器權重: 2.0111135958993237e-05
#
# SAMME弱分類器權重: 2.010914517863109e-05
#
# SAMME弱分類器權重: 1.608572367251748e-05
#
# SAMME弱分類器權重: 1.608444982088876e-05
#
# SAMME弱分類器權重: 1.608317606762259e-05
#
# SAMME弱分類器權重: 1.2061426809609104e-05
#
# SAMME弱分類器權重: 1.2060710435296437e-05
#
# SAMME弱分類器權重: 1.2059994101394889e-05
#
# SAMME弱分類器權重: 8.039518539804064e-06
#
# SAMME弱分類器權重: 8.039200207005192e-06
#
# SAMME弱分類器權重: 8.038881885974487e-06
#
# SAMME弱分類器權重: 8.038563577156038e-06
#
# SAMME弱分類器權重: 8.038245281438013e-06
#
# SAMME弱分類器權重: 4.018963498826012e-06
#
# SAMME弱分類器權重: 4.018883930127752e-06
#
# SAMME弱分類器權重: 4.0188043638719664e-06
#
# SAMME弱分類器權重: 4.018724799170481e-06
#
# SAMME弱分類器權重: 4.018645236023294e-06
#
# SAMME弱分類器權重: 4.018565674208365e-06
#
# SAMME弱分類器權重: 4.01848611550204e-06
#
# SAMME弱分類器權重: 4.0184065559075345e-06
#
# SAMME弱分類器權重: 4.018326999199591e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.4988009592326139
#
# 這次的AUC :  0.6760784576662816
#
# SAMME弱分類器權重: 0.7811765253015762
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.4764188649080736
#
# 這次的AUC :  0.6626906909697818
#
# SAMME弱分類器權重: 0.7841286051184362
#
# SAMME弱分類器權重: 0.33561915908411727
#
# SAMME弱分類器權重: 0.1990070205746829
#
# SAMME弱分類器權重: 0.0544067785863642
#
# SAMME弱分類器權重: 0.03746294384557219
#
# SAMME弱分類器權重: 0.027380365808104677
#
# SAMME弱分類器權重: 0.020838679623608986
#
# SAMME弱分類器權重: 0.016330440285653426
#
# SAMME弱分類器權重: 0.013093698526999337
#
# SAMME弱分類器權重: 0.010681367837495919
#
# SAMME弱分類器權重: 0.008841232594288222
#
# SAMME弱分類器權重: 0.012149476688450483
#
# SAMME弱分類器權重: 0.010072932401786158
#
# SAMME弱分類器權重: 0.008466023865087564
#
# SAMME弱分類器權重: 0.0071873830425179894
#
# SAMME弱分類器權重: 0.0061616646890364215
#
# SAMME弱分類器權重: 0.005320263151557092
#
# SAMME弱分類器權重: 0.004623721513758098
#
# SAMME弱分類器權重: 0.004043503847347437
#
# SAMME弱分類器權重: 0.0035474276832677164
#
# SAMME弱分類器權重: 0.003131628956926166
#
# SAMME弱分類器權重: 0.0027735719454840815
#
# SAMME弱分類器權重: 0.002460922656303333
#
# SAMME弱分類器權重: 0.0021942414035405846
#
# SAMME弱分類器權重: 0.0019591348765015757
#
# SAMME弱分類器權重: 0.0017536621751559796
#
# SAMME弱分類器權重: 0.0015724422419627346
#
# SAMME弱分類器權重: 0.0014142349726486846
#
# SAMME弱分類器權重: 0.0012706084350683849
#
# SAMME弱分類器權重: 0.0011482192532554071
#
# SAMME弱分類器權重: 0.0010353673293901251
#
# SAMME弱分類器權重: 0.0009352817976138137
#
# SAMME弱分類器權重: 0.0008475440475426364
#
# SAMME弱分類器權重: 0.0007646181676123148
#
# SAMME弱分類器權重: 0.0006934698595624395
#
# SAMME弱分類器權重: 0.0006302665238252189
#
# SAMME弱分類器權重: 0.0005712798434843268
#
# SAMME弱分類器權重: 0.0005199369446405451
#
# SAMME弱分類器權重: 0.000472573556886715
#
# SAMME弱分類器權重: 0.00042910939546167984
#
# SAMME弱分類器權重: 0.0003894739280797927
#
# SAMME弱分類器權重: 0.00035710653357135024
#
# SAMME弱分類器權重: 0.00032493799295925645
#
# SAMME弱分類器權重: 0.0002964381495242679
#
# SAMME弱分類器權重: 0.00026808503771535503
#
# SAMME弱分類器權重: 0.0002468174931922523
#
# SAMME弱分類器權重: 0.0002221698303459832
#
# SAMME弱分類器權重: 0.00020455262381418175
#
# SAMME弱分類器權重: 0.00018699839645316296
#
# SAMME弱分類器權重: 0.0001695018436377331
#
# SAMME弱分類器權重: 0.0001555135465303725
#
# SAMME弱分類器權重: 0.00014156355002631018
#
# SAMME弱分類器權重: 0.00012764849481812927
#
# SAMME弱分類器權重: 0.00011721246108702314
#
# SAMME弱分類器權重: 0.00010679805280003061
#
# SAMME弱分類器權重: 9.984637216961561e-05
#
# SAMME弱分類器權重: 8.946590143357012e-05
#
# SAMME弱分類器權重: 8.254128300588566e-05
#
# SAMME弱分類器權重: 7.562679294356801e-05
#
# SAMME弱分類器權重: 6.872160254778465e-05
#
# SAMME弱分類器權重: 6.182488499778564e-05
#
# SAMME弱分類器權重: 5.836930363593995e-05
#
# SAMME弱分類器權重: 5.148494492042196e-05
#
# SAMME弱分類器權重: 4.80383055854383e-05
#
# SAMME弱分類器權重: 4.4594599966730404e-05
#
# SAMME弱分類器權重: 4.1153622111456815e-05
#
# SAMME弱分類器權重: 3.771516634124091e-05
#
# SAMME弱分類器權重: 3.42790272308655e-05
#
# SAMME弱分類器權重: 3.0844999587854686e-05
#
# SAMME弱分類器權重: 2.7412878434275293e-05
#
# SAMME弱分類器權重: 2.39824589865391e-05
#
# SAMME弱分類器權重: 2.3979126070364694e-05
#
# SAMME弱分類器權重: 2.055068023661695e-05
#
# SAMME弱分類器權重: 2.054823223516126e-05
#
# SAMME弱分類器權重: 1.712148710045869e-05
#
# SAMME弱分類器權重: 1.7119787497344478e-05
#
# SAMME弱分類器權重: 1.369447044960245e-05
#
# SAMME弱分類器權重: 1.369338291688762e-05
#
# SAMME弱分類器權重: 1.0269221601595746e-05
#
# SAMME弱分類器權重: 1.0268609960699317e-05
#
# SAMME弱分類器權重: 1.02679983548852e-05
#
# SAMME弱分類器權重: 1.0267386786151778e-05
#
# SAMME弱分類器權重: 6.844516835029207e-06
#
# SAMME弱分類器權重: 6.844245058511775e-06
#
# SAMME弱分類器權重: 6.843973291764164e-06
#
# SAMME弱分類器權重: 6.8437015361186345e-06
#
# SAMME弱分類器權重: 6.843429791797228e-06
#
# SAMME弱分類器權重: 6.843158057911772e-06
#
# SAMME弱分類器權重: 3.4214431662928503e-06
#
# SAMME弱分類器權重: 3.4213752384176763e-06
#
# SAMME弱分類器權重: 3.4213073116527174e-06
#
# SAMME弱分類器權重: 3.4212393859979725e-06
#
# SAMME弱分類器權重: 3.42117146189753e-06
#
# SAMME弱分類器權重: 3.421103538907303e-06
#
# SAMME弱分類器權重: 3.4210356172493333e-06
#
# SAMME弱分類器權重: 3.420967696701579e-06
#
# SAMME弱分類器權重: 3.420899778596302e-06
#
# SAMME弱分類器權重: 3.4208318613791957e-06
#
# SAMME弱分類器權重: 3.420763944162085e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.48979591836734687
#
# 這次的AUC :  0.6713232147801355
#
# SAMME弱分類器權重: 0.7828334335580074
#
# SAMME弱分類器權重: 0.3341425881317048
#
# SAMME弱分類器權重: 0.19933359988534521
#
# SAMME弱分類器權重: 0.05474226958177598
#
# SAMME弱分類器權重: 0.03767677602922182
#
# SAMME弱分類器權重: 0.02752166310557759
#
# SAMME弱分類器權重: 0.02094741097877878
#
# SAMME弱分類器權重: 0.01642077989418033
#
# SAMME弱分類器權重: 0.013163682133434391
#
# SAMME弱分類器權重: 0.010745466653842514
#
# SAMME弱分類器權重: 0.008894950201244317
#
# SAMME弱分類器權重: 0.0074422706889953815
#
# SAMME弱分類器權重: 0.00628948650050708
#
# SAMME弱分類器權重: 0.00535854282480681
#
# SAMME弱分類器權重: 0.004594838851746573
#
# SAMME弱分類器權重: 0.006297355852692237
#
# SAMME弱分類器權重: 0.005405653906248703
#
# SAMME弱分類器權重: 0.004670207350966492
#
# SAMME弱分類器權重: 0.004056341170890131
#
# SAMME弱分類器權重: 0.0035433501234398536
#
# SAMME弱分類器權重: 0.003105151585965426
#
# SAMME弱分類器權重: 0.0027355745795161865
#
# SAMME弱分類器權重: 0.0024129565801579407
#
# SAMME弱分類器權重: 0.0021381313138872375
#
# SAMME弱分類器權重: 0.0018959907685804395
#
# SAMME弱分類器權重: 0.001688665586812211
#
# SAMME弱分類器權重: 0.0015064206756202456
#
# SAMME弱分類器權重: 0.001344093978732533
#
# SAMME弱分類器權重: 0.0012047473506630964
#
# SAMME弱分類器權重: 0.0010757595688464967
#
# SAMME弱分類器權重: 0.000968395534618141
#
# SAMME弱分類器權重: 0.0008664969166865066
#
# SAMME弱分類器權重: 0.0007814307830707704
#
# SAMME弱分類器權重: 0.0007012434813294693
#
# SAMME弱分類器權重: 0.0006334500021585652
#
# SAMME弱分類器權重: 0.0005701541945528777
#
# SAMME弱分類器權重: 0.0005150572869658267
#
# SAMME弱分類器權重: 0.0004642138387834633
#
# SAMME弱分類器權重: 0.0004175414083656748
#
# SAMME弱分類器權重: 0.0003787555184206568
#
# SAMME弱分類器權重: 0.00034020430639256885
#
# SAMME弱分類器權重: 0.00030941096176065466
#
# SAMME弱分類器權重: 0.0002787706661402434
#
# SAMME弱分類器權重: 0.000252030223454952
#
# SAMME弱分類器權重: 0.00022915559124627116
#
# SAMME弱分類器權重: 0.00020636584634778937
#
# SAMME弱分類器權重: 0.0001874007627191424
#
# SAMME弱分類器權重: 0.00016849350499986514
#
# SAMME弱分類器權重: 0.00015337934938811746
#
# SAMME弱分類器權重: 0.00013830300160852502
#
# SAMME弱分類器權重: 0.00012699601930491155
#
# SAMME弱分類器權重: 0.00011197977748012498
#
# SAMME弱分類器權重: 0.0001044522960314624
#
# SAMME弱分類器權重: 9.320920642587799e-05
#
# SAMME弱分類器權重: 8.570996598933009e-05
#
# SAMME弱分類器權重: 7.449641863729055e-05
#
# SAMME弱分類器權重: 7.074353444215645e-05
#
# SAMME弱分類器權重: 6.327300212739753e-05
#
# SAMME弱分類器權重: 5.581030191046966e-05
#
# SAMME弱分類器權重: 5.2074123396514696e-05
#
# SAMME弱分類器權重: 4.83411209218575e-05
#
# SAMME弱分類器權重: 4.089348223465668e-05
#
# SAMME弱分類器權重: 3.716778487285907e-05
#
# SAMME弱分類器權重: 3.344437393580911e-05
#
# SAMME弱分類器權重: 3.343840589571176e-05
#
# SAMME弱分類器權重: 2.9717723466462346e-05
#
# SAMME弱分類器權重: 2.5998883427885842e-05
#
# SAMME弱分類器權重: 2.228166425230479e-05
#
# SAMME弱分類器權重: 2.227901349624223e-05
#
# SAMME弱分類器權重: 1.8563635875305842e-05
#
# SAMME弱分類器權重: 1.856179550275256e-05
#
# SAMME弱分類器權重: 1.4847964247923156e-05
#
# SAMME弱分類器權重: 1.484678663874484e-05
#
# SAMME弱分類器權重: 1.4845609121934322e-05
#
# SAMME弱分類器權重: 1.1133323772306507e-05
#
# SAMME弱分類器權重: 1.113266152342952e-05
#
# SAMME弱分類器權重: 1.11319993125213e-05
#
# SAMME弱分類器權重: 7.4208914262267435e-06
#
# SAMME弱分類器權重: 7.42059714492407e-06
#
# SAMME弱分類器權重: 7.420302874501415e-06
#
# SAMME弱分類器權重: 7.420008615624906e-06
#
# SAMME弱分類器權重: 7.419714369182716e-06
#
# SAMME弱分類器權重: 3.709710065759708e-06
#
# SAMME弱分類器權重: 3.7096365099824365e-06
#
# SAMME弱分類器權重: 3.7095629553153787e-06
#
# SAMME弱分類器權重: 3.7094894028687535e-06
#
# SAMME弱分類器權重: 3.7094158517543853e-06
#
# SAMME弱分類器權重: 3.7093422999738804e-06
#
# SAMME弱分類器權重: 3.709268751301983e-06
#
# SAMME弱分類器權重: 3.709195203962343e-06
#
# SAMME弱分類器權重: 3.7091216577329163e-06
#
# SAMME弱分類器權重: 3.7090481132798346e-06
#
# SAMME弱分類器權重: 3.7089745699369666e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 這次的f1 :  0.45980707395498394
#
# 這次的AUC :  0.6525711696745451
#
# SAMME弱分類器權重: 0.7833255250789476
#
# SAMME弱分類器權重: 0.3342363944256687
#
# SAMME弱分類器權重: 0.19926804821566346
#
# SAMME弱分類器權重: 0.06351161012588245
#
# SAMME弱分類器權重: 0.04280703276359251
#
# SAMME弱分類器權重: 0.03091818965802531
#
# SAMME弱分類器權重: 0.02338907762710643
#
# SAMME弱分類器權重: 0.018295731875200897
#
# SAMME弱分類器權重: 0.01467559184133827
#
# SAMME弱分類器權重: 0.01200553686152733
#
# SAMME弱分類器權重: 0.009979447373272159
#
# SAMME弱分類器權重: 0.00840017708064099
#
# SAMME弱分類器權重: 0.009138166926780461
#
# SAMME弱分類器權重: 0.007774576056644847
#
# SAMME弱分類器權重: 0.006678933253109879
#
# SAMME弱分類器權重: 0.005783770950421749
#
# SAMME弱分類器權重: 0.005046617769525394
#
# SAMME弱分類器權重: 0.00442891394416018
#
# SAMME弱分類器權重: 0.003905916072417351
#
# SAMME弱分類器權重: 0.003460413626906775
#
# SAMME弱分類器權重: 0.0030813986173343394
#
# SAMME弱分類器權重: 0.0027523033800635833
#
# SAMME弱分類器權重: 0.0024655093910615745
#
# SAMME弱分類器權重: 0.0022143259299722312
#
# SAMME弱分類器權重: 0.0019962636359671993
#
# SAMME弱分類器權重: 0.0018023920597411852
#
# SAMME弱分類器權重: 0.001631238169226917
#
# SAMME弱分類器權重: 0.0014781958231164744
#
# SAMME弱分類器權重: 0.0013423141292927625
#
# SAMME弱分類器權重: 0.0012227778248565797
#
# SAMME弱分類器權重: 0.001112346138089259
#
# SAMME弱分類器權重: 0.001013846223747002
#
# SAMME弱分類器權重: 0.0009268272230992108
#
# SAMME弱分類器權重: 0.0008476899279152537
#
# SAMME弱分類器權重: 0.0007761666746971042
#
# SAMME弱分類器權重: 0.0007088449012874565
#
# SAMME弱分類器權重: 0.0006519053132202674
#
# SAMME弱分類器權重: 0.0005956584570009612
#
# SAMME弱分類器權重: 0.0005463239024375129
#
# SAMME弱分類器權重: 0.0005037582360211136
#
# SAMME弱分類器權重: 0.0004616000740430759
#
# SAMME弱分類器權重: 0.0004260348421017205
#
# SAMME弱分類器權重: 0.00039076052754109786
#
# SAMME弱分類器權重: 0.00035884665799864153
#
# SAMME弱分類器權重: 0.00033024175705018995
#
# SAMME弱分類器權重: 0.00030490079009400887
#
# SAMME弱分類器權重: 0.0002797107058563179
#
# SAMME弱分類器權重: 0.0002577273532669977
#
# SAMME弱分類器權重: 0.00023891856332222054
#
# SAMME弱分類器權重: 0.00022019818373115435
#
# SAMME弱分類器權重: 0.00020155937006295315
#
# SAMME弱分類器權重: 0.00018604524978902686
#
# SAMME弱分類器權重: 0.00017363470118372896
#
# SAMME弱分類器權重: 0.00015822405300602087
#
# SAMME弱分類器權重: 0.00014894157897730437
#
# SAMME弱分類器權重: 0.00013664980858629606
#
# SAMME弱分類器權重: 0.0001243917512773523
#
# SAMME弱分類器權重: 0.0001151959214991345
#
# SAMME弱分類器權重: 0.00010602133228234454
#
# SAMME弱分類器權重: 9.989339736673723e-05
#
# SAMME弱分類器權重: 9.075258639951711e-05
#
# SAMME弱分類器權重: 8.465188301451689e-05
#
# SAMME弱分類器權重: 7.856155228166979e-05
#
# SAMME弱分類器權重: 7.248086147149738e-05
#
# SAMME弱分類器權重: 6.64090798062524e-05
#
# SAMME弱分類器權重: 6.034547830950889e-05
#
# SAMME弱分類器權重: 5.730540353675668e-05
#
# SAMME弱分類器權重: 5.125388268796121e-05
#
# SAMME弱分類器權重: 4.822264031504593e-05
#
# SAMME弱分類器權重: 4.519434060825409e-05
#
# SAMME弱分類器權重: 4.2168801927332956e-05
#
# SAMME弱分類器權重: 3.914584290957273e-05
#
# SAMME弱分類器權重: 3.612528244983235e-05
#
# SAMME弱分類器權重: 3.310693968922396e-05
#
# SAMME弱分類器權重: 3.0090633989364426e-05
#
# SAMME弱分類器權重: 2.7076184921058602e-05
#
# SAMME弱分類器權重: 2.7071338772441962e-05
#
# SAMME弱分類器權重: 2.405910531633354e-05
#
# SAMME弱分類器權重: 2.104836791429822e-05
#
# SAMME弱分類器權重: 2.1045437792539626e-05
#
# SAMME弱分類器權重: 1.803643549132678e-05
#
# SAMME弱分類器權重: 1.8034283341048327e-05
#
# SAMME弱分類器權重: 1.502677620447224e-05
#
# SAMME弱分類器權重: 1.5025282008619596e-05
#
# SAMME弱分類器權重: 1.5023787960200123e-05
#
# SAMME弱分類器權重: 1.2017835246277199e-05
#
# SAMME弱分類器權重: 1.2016879242720999e-05
#
# SAMME弱分類器權重: 1.2015923314658141e-05
#
# SAMME弱分類器權重: 9.011225596906979e-06
#
# SAMME弱分類器權重: 9.01068797181095e-06
#
# SAMME弱分類器權重: 9.010150378244684e-06
#
# SAMME弱分類器權重: 9.009612817096347e-06
#
# SAMME弱分類器權重: 6.006050192181211e-06
#
# SAMME弱分類器權重: 6.005811304263216e-06
#
# SAMME弱分類器權重: 6.005572425226895e-06
#
# SAMME弱分類器權重: 6.00533355529429e-06
#
# SAMME弱分類器權重: 6.0050946966858355e-06
#
# SAMME弱分類器權重: 6.004855845626796e-06
#
# SAMME弱分類器權重: 6.004617005003732e-06
#
# SAMME弱分類器權重: 3.002189086708077e-06
#
# 這次的f1 :  0.504266873545384
#
# 這次的AUC :  0.6806992373329306
#
# ans_auc :  0.6693410220497945
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
